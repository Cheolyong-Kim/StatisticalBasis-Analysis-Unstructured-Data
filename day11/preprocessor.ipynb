# %%
import pandas as pd
import numpy as np
from konlpy.tag import Okt
from string import punctuation
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import pickle

# %%
data = pd.read_table('ck_data.txt', names = ['label', 'reviews'])
data = data.drop_duplicates(subset = ['reviews'])
data['label'].astype(int)
# Out:
# 0        0
# 1        0
# 2        1
# 3        1
# 4        1
#         ..
# 99995    0
# 99996    0
# 99997    0
# 99998    1
# 99999    1
# Name: label, Length: 99892, dtype: int32

# %%
st = set(['은', '는', '이', '가', '을', '를', '도', '에게', '로', '에', '요', '의', '우리', '저희', '나', '님', '게임', '너무', '그냥', '좀', '더', '정말', '다', '그리고', '하지만', '그래서'])
p = list(punctuation)
st.update(p)

# %%
data['reviews'] = data['reviews'].str.replace('[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]', '')
data['reviews'] = data['reviews'].str.replace('^ +', '')
data['reviews'] = data['reviews'].replace('', np.nan)
data = data.dropna(how = 'any', axis = 0)
# Out:
# C:\Users\김철용\AppData\Local\Temp/ipykernel_1720/2108472703.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['reviews'] = data['reviews'].str.replace('[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]', '')
# C:\Users\김철용\AppData\Local\Temp/ipykernel_1720/2108472703.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['reviews'] = data['reviews'].str.replace('^ +', '')

# %%
okt = Okt()
okt_l = []
for sentence in data['reviews']:
    okt_l.append(okt.morphs(sentence))

# %%
s_otk_l = []
for sentence in okt_l:
    s_otk_l.append([word for word in sentence if word not in st])
s_otk_l
# Out:
# [['노래', '적음'],
#  ['돌겠네', '진짜', '황숙', '아', '어크', '공장', '그만', '돌려라', '죽는다'],
#  ['막노동', '체험판', '막노동', '하는', '사람', '인데', '장비', '내', '사야', '돼', '뭐', '지'],
#  ['차악차악차악', '이래서', '왕국', '되찾을', '수', '있는거야'],
#  ['시간', '때우기에', '좋음', '도전', '과제', '시간', '이면', '깰', '수', '있어요'],
#  ['역시', '재미있네요', '전작', '에서', '할수', '없었던', '자유로운', '덱', '빌딩', '좋네요'],
#  ['재미있었습니다'],
#  ['은근', '쉽지만', '은근', '어려운'],
#  ['베',
#   'ㅈ',
#   '스',
#   '개',
#   'ㅐ',
#   '끼',
#   '들',
#   '아',
#   '시작',
#   '할',
#   '때',
#   '체스판',
#   '돌아가는거',
#   '분동',
#   '안',
#   '번',
#   '봤',
#   'ㅈㄴ',
#   '빡치네',
#   '진짜',
#   '무한',
#   '로딩',
#   '버그',
#   '안',
#   '쳐',
#   '고치냐',
#   '겜',
#   '하지말라는',
#   '거',
#   '냐'],
#  ['시간', '분동', '안', '스트레스', '풀림', 'ㄹㅇ'],
#  ['걍', '겜임', '계정', '못', '만들어', '미친', '겜'],
#  ['관람객', '호랑이', '불가'],
#  ['재미', '쩡', '초반', '힘들어여', '도트', '라서', '조아'],
#  ['포켓볼',
#   '몰랐는데',
#   '걸',
#   '배워',
#   '갑니다',
#   '심심할',
#   '때',
#   '하면',
#   '좋아요',
#   '컴퓨터',
#   '상대',
#   '하는거',
#   '제대로',
#   '이겨',
#   '보고',
#   '싶은데',
#   '잘',
#   '안되네요'],
#  ['트레이아크', '사랑', '해요', '핰핰'],
#  ['좆망', '겜', '하지마', '무슨', '처음', '키', '자마자', '매칭', '왜', '렙', '하고', '매칭', '되냐'],
#  ['뭐랄까',
#   '다크',
#   '소울',
#   '하',
#   '느낌',
#   '이에요',
#   '죽으면',
#   '돈',
#   '다날',
#   '라가',
#   '방식',
#   '렙업',
#   '하면서',
#   '무한',
#   '반복',
#   '인거',
#   '같은데',
#   '재미있습니다',
#   '클래스',
#   '은근',
#   '많은거',
#   '같고',
#   '또',
#   '캐릭터',
#   '계속',
#   '추가',
#   '할',
#   '예정',
#   '인가',
#   '같고',
#   '할',
#   '요소',
#   '하고',
#   '매번',
#   '던전',
#   '바뀌고',
#   '재미있습니다',
#   '돈',
#   '아깝지',
#   '않다고',
#   '생각',
#   '드',
#   '네',
#   'ㅊㅊ'],
#  ['원하는거',
#   '보실려면',
#   '홈페이지',
#   '가셔서',
#   '패치',
#   '사셔야',
#   '합니다',
#   '패치',
#   '만원',
#   '이라',
#   '사실',
#   '상',
#   '만원',
#   '주고',
#   '사는',
#   '건데',
#   'ㅁ',
#   '좋던데요'],
#  ['안해',
#   '썩을',
#   '까진',
#   '대충',
#   '슥',
#   '슥',
#   '해도',
#   '되더니',
#   '에서',
#   '판때',
#   '기를',
#   '직접',
#   '사용',
#   '하는데',
#   '판',
#   '밟는',
#   '순간',
#   '서있는',
#   '땅',
#   '변해',
#   '버리니까',
#   '뭔가',
#   '억울하면서',
#   '하기',
#   '싫어졌음',
#   '그래도',
#   '일단',
#   '놈',
#   '못잡으면',
#   '왠지',
#   '못',
#   '깨서',
#   '안',
#   '하는것',
#   '같아서',
#   '깨고',
#   '접음'],
#  ['우웩'],
#  ['로지텍', '마우스', '드디어', '일', '한', '매크로', '없는', '흑우', '없', '제'],
#  ['디스플레이', '다소', '버그', '있지만', '자체', '훌륭하다'],
#  ['압도',
#   '적',
#   '긍정',
#   '적',
#   '이든',
#   '뭐',
#   '든',
#   '랑',
#   '안',
#   '맞으면',
#   '노잼',
#   '이라',
#   '는걸',
#   '새삼',
#   '느끼게',
#   '해준'],
#  ['명중', '률', '면', '인간', '적', '으로', '맞아', '야하는거', '아니냐'],
#  ['난', '되게', '재밋게햇넹', 'ㅋㅋㅋㅋ', '딱', '킬링', '타', '임용', '으로', '적당한듯'],
#  ['쓰레기', '절때', '사지마'],
#  ['재미있는', '이지만', '티어', '올리는데', '오래', '걸림'],
#  ['걍', '겜', '하실려면', '어려우니까', '무료', '겜', '인', '하세요'],
#  ['단점'],
#  ['처음',
#   '에는',
#   '그런',
#   '횡스',
#   '크롤',
#   '액션',
#   '정도',
#   '였으나',
#   '단계',
#   '넘어갈수록',
#   '개발자',
#   '재치',
#   '엿',
#   '보이',
#   '이네',
#   '중국',
#   '많이',
#   '발전',
#   '했다는걸',
#   '느낄수',
#   '있는',
#   '이었습니다'],
#  ['아', '중독', '성', '있네요', '한번', '하면', '멈추기가', '힘듬'],
#  ['개', '슈레', '기'],
#  ['좋은', 'ㅋㅋㅋ'],
#  ['세',
#   '일',
#   '든',
#   '몇',
#   '퍼센트',
#   '하더라도',
#   '사지말라',
#   '한마디',
#   '면',
#   '될듯',
#   '하다',
#   '사면',
#   '그',
#   '순간',
#   '넌',
#   '호갱',
#   '된거',
#   '무료',
#   '뿌리는걸',
#   '받았다면',
#   '카드',
#   '만',
#   '받아라',
#   '난',
#   '게',
#   '어떻게',
#   '팔리게',
#   '됬는지',
#   '그게',
#   '참',
#   '궁금하다'],
#  ['무료', '겜', '적당함'],
#  ['컴퓨터',
#   '하지',
#   '마세요',
#   '걍',
#   '플스',
#   '하세요',
#   '혼자',
#   '이상한데',
#   '낑겨서',
#   '말',
#   '안되게',
#   '버벅',
#   '거림',
#   '시작',
#   '한지',
#   '시간',
#   '만',
#   '지워',
#   '버림니다',
#   '내용',
#   '보기전에',
#   '조',
#   '작',
#   '감',
#   '쓰레기',
#   '인',
#   '패드',
#   '랑',
#   '키',
#   '보드',
#   '다해',
#   '봤는데',
#   '혼자',
#   '이상한데',
#   '낑김'],
#  ['레이싱',
#   '즐길',
#   '수',
#   '있다',
#   '다른',
#   '오브젝트',
#   '와',
#   '차량',
#   '파괴',
#   '할',
#   '수',
#   '있으며',
#   '드리프트',
#   '조금',
#   '힘들다',
#   '레이싱',
#   '질린다면',
#   '트랙',
#   '쉽다면',
#   '마이',
#   '시티',
#   '통해',
#   '서',
#   '자신',
#   '트랙',
#   '만들',
#   '수',
#   '있습니다'],
#  ['훌륭합니다', '절', '대', '마', '코', '해'],
#  ['거', '어뜨', '게', '한', '굳어', '함'],
#  ['계속',
#   '적',
#   '으로',
#   '멈춤',
#   '현상',
#   '발생',
#   '왠만하면',
#   '전작',
#   '재밌어서',
#   '할려',
#   '했는데',
#   '도저히',
#   '불가능하여',
#   '포기'],
#  ['밸브',
#   '만든',
#   '인가요',
#   '뭔가',
#   '하프라이프',
#   '같은',
#   '느낌',
#   '드',
#   '고',
#   '그래픽',
#   '이랑',
#   '상대',
#   '적',
#   '외계',
#   '생명체',
#   '이고',
#   '협동',
#   '이라니',
#   '역시',
#   '같이',
#   '하니까',
#   '재밌네여',
#   '추천',
#   '합니다',
#   '무료',
#   '겜',
#   '이니',
#   '좋',
#   '네',
#   '여',
#   'ㅎㅎ',
#   '게다가',
#   '질',
#   '양',
#   '하고',
#   '싸우는',
#   'ㅋㅋㅋㅋ'],
#  ['재미있다',
#   '좀비',
#   '모드',
#   '라거',
#   '하는',
#   '모드',
#   '지원',
#   '아는',
#   '사람',
#   '없이',
#   '혼자',
#   '하기엔',
#   '조금',
#   '모자란',
#   '느낌'],
#  ['심각하게', '노잼', '입니다'],
#  ['처음',
#   '부터',
#   '긑',
#   '까지',
#   '현질',
#   '만',
#   '유도',
#   '하는',
#   '어느',
#   '시점',
#   '되면',
#   '절대로',
#   '이길수',
#   '없는',
#   '사람',
#   '들',
#   '하고만',
#   '팀',
#   '매',
#   '치가',
#   '됨',
#   '걍',
#   '하지말아야',
#   '할',
#   '게다가',
#   '서버',
#   '엄청',
#   '느림',
#   '돈',
#   '밖에',
#   '모르는',
#   '게'],
#  ['갓', '겜', '세', '일', '할', '때', '꼭', '사셈'],
#  ['베데스다', '와', '돼지', '새끼', '법규'],
#  ['마테', '체', '썰고', '다니는것이', '재밌다', '없던', '스트레스', '풀리는', '기분'],
#  ['실제', '카지노', '에서', '포커', '하는듯', '한', '기분', '들어서', '좋았음', '잘', '만든것', '같아요'],
#  ['왜', '도트겜', '인데', '프레임', '많이', '끊기는거지', '해보고싶은데'],
#  ['자체',
#   '외국',
#   '섭',
#   '만',
#   '봤을',
#   '때',
#   '좋은데',
#   '좆목',
#   '잼민',
#   '들',
#   '여왕벌',
#   '삼위일체',
#   '이루는',
#   'ㅆㅉㄸ',
#   '한국',
#   '섭',
#   '가지',
#   '않는게',
#   '정신건강',
#   '로움',
#   '한국',
#   '섭',
#   '들어갈려면',
#   '절차',
#   '금융',
#   '보안',
#   '프로그램',
#   '설치',
#   '급',
#   '이다'],
#  ['쓸모없는', '공군'],
#  ['솔', '까', '무료', '라고', '하기엔', '퀄', '개쩜'],
#  ['서든어택',
#   '표절',
#   '함',
#   'ㅋㅋㅋㅋㅋ',
#   '서든어택',
#   '총',
#   '쏘고',
#   '움직',
#   '이고',
#   '한',
#   '방',
#   '죽는데',
#   '겜',
#   '배낌',
#   '에혀',
#   '개',
#   '노잼',
#   '망겜',
#   '이렇지',
#   '븅쉬갬',
#   'ㅋ'],
#  ['허', '난', '운다'],
#  ['퇴근',
#   '하고',
#   '하고',
#   '싶은데',
#   '빡겜할',
#   '기운',
#   '없고',
#   '축',
#   '늘어져서',
#   '쉬엄',
#   '쉬엄',
#   '한',
#   '극',
#   '후반',
#   '부',
#   '까지',
#   '진행',
#   '했지만',
#   '엔딩',
#   '얼마',
#   '안남았음에도',
#   '참지',
#   '못',
#   '하고',
#   '찍',
#   '쌌다',
#   '드래곤볼',
#   '좋아하니깐',
#   '머',
#   '하는',
#   '동안',
#   '나쁘지는',
#   '않았지만',
#   '남',
#   '추천',
#   '도저히',
#   '못',
#   '하겠다'],
#  ['레벨',
#   '하나',
#   '깰',
#   '때',
#   '마다',
#   '해당',
#   '멜로디',
#   '다시',
#   '확인',
#   '시켜주는',
#   '게',
#   '신경',
#   '과',
#   '하게',
#   '자극',
#   '합니다',
#   '그렇다고',
#   '딱히',
#   '합주',
#   '자극',
#   '적은',
#   '건',
#   '아니었던',
#   '것',
#   '같아요',
#   '퍼즐',
#   '난이도',
#   '서서히',
#   '높아지다가',
#   '갑자기',
#   '차원',
#   '수가',
#   '하나',
#   '늘어',
#   '버리네요',
#   '전',
#   '못',
#   '하겠어요'],
#  ['더럽게', '어렵다', '그래픽', '좋더라', '노잼'],
#  ['탈출', '하는거에만', '열중', '하고', '외', '아무', '생각', '안', '들어서', '좋다고', '하긴', '애매해요'],
#  ['삭제', '해도', '다시', '생각나서', '하게', '되네요'],
#  ['한', '패가', '없다', '싯팔'],
#  ['점점', '내', '가해자', '이고', '악마', '피해자', '같다', '걍', '떄려', '부셔야지', '이히', '힣'],
#  ['카악', '퉤'],
#  ['싱글',
#   '미션',
#   '많았으면',
#   '하는',
#   '아쉬움',
#   '남는다',
#   '홈월드',
#   '플레이',
#   '한',
#   '기억',
#   '없다면',
#   '시리즈',
#   '구매',
#   '할',
#   '이유',
#   '있을까',
#   '올드팬',
#   '아니라면',
#   '구매',
#   '하지',
#   '않는',
#   '게',
#   '나을수도',
#   '있다',
#   '대체',
#   '할만',
#   '한',
#   '들',
#   '많다'],
#  ['머리', '쓰는', '퍼즐게임', '좋아하는', '유저', '라면', '필구'],
#  ['쿠키',
#   '클리커',
#   '스팀',
#   '판',
#   '굳이',
#   '켜놓지',
#   '않아도',
#   '돈',
#   '차곡',
#   '차곡',
#   '쌓이니',
#   '웹게임',
#   '처럼',
#   '어쩌다',
#   '한번',
#   '씩',
#   '만',
#   '들어와서',
#   '업그레이드',
#   '해주신',
#   '뒤',
#   '나가는것만으로도',
#   '충분히',
#   '즐길수',
#   '있을것',
#   '입니다'],
#  ['들이',
#   '하는',
#   '거',
#   '보고',
#   '받았는데',
#   '스토리',
#   '짧고',
#   '쉽다',
#   '어렵게',
#   '만들어',
#   '주거',
#   '스토리',
#   '늘려라',
#   '산',
#   '게',
#   '아까워',
#   '진다'],
#  ['열차', '루트', '같이', '묶어서', '파는게', '좋을것', '같네요', '초보자', '들', '진짜', '헤매거든요'],
#  ['뿡', '밑', '탙'],
#  ['구입',
#   '하고',
#   '몇',
#   '년',
#   '째',
#   '할줄',
#   '몰라',
#   '안',
#   '하다가',
#   '울트라',
#   '와이드',
#   '모니터',
#   '구입',
#   '후',
#   '테스트',
#   '삼아',
#   '해보았는데',
#   '눈',
#   '깔',
#   '돌아가는구만',
#   '레이싱',
#   '역시',
#   '울트라',
#   '와이드',
#   '모니터',
#   '해야겠군',
#   '근데',
#   '난',
#   '역시',
#   '실력',
#   '늘',
#   '지',
#   '않는구만'],
#  ['장',
#   '국산',
#   '예쁜',
#   '일러스트',
#   '단',
#   '빠져들',
#   '것',
#   '만',
#   '같은데',
#   '동시',
#   '몰입',
#   '이상하게',
#   '안',
#   '되는',
#   '스토리',
#   '부분',
#   '적',
#   '인',
#   '국어',
#   '책',
#   '읽기',
#   '수준',
#   '연기',
#   '하는',
#   '다수',
#   '캐릭터',
#   '기본',
#   '적',
#   '으로',
#   '재미',
#   '없음',
#   '혼자',
#   '만',
#   '커플',
#   '없는',
#   '영조'],
#  ['배경화면', '보려고', '별로', '안', '하게', '됨'],
#  ['개',
#   '보는',
#   '것',
#   '뿐',
#   '만',
#   '아니라',
#   '무려',
#   '개',
#   '쓰다듬을',
#   '수도',
#   '있답니다',
#   '제목',
#   '반도',
#   '표현',
#   '못',
#   '하는',
#   '죠'],
#  ['난이도',
#   '높다',
#   '스테이지',
#   '부터',
#   '절망',
#   '맛보게',
#   '될것이다',
#   '장르',
#   '슈팅',
#   '인',
#   '만큼',
#   '매우',
#   '좋다',
#   '창',
#   '모드',
#   '고정',
#   '안되는게',
#   '아쉽다',
#   '알트',
#   '앤터',
#   '일일',
#   '히',
#   '설정',
#   '해야',
#   '함'],
#  ['두',
#   '명',
#   '서',
#   '멀티',
#   '하다가',
#   '배아',
#   '파',
#   '뒤질',
#   '뻔함',
#   '웃음',
#   '으로',
#   '운동',
#   '한다는',
#   '얘기',
#   '실감',
#   '함',
#   '분동',
#   '안',
#   '미친',
#   '거마',
#   '냥',
#   '웃었더니',
#   '배',
#   '찢어질거',
#   '같고',
#   '광대뼈',
#   '쪼개질거',
#   '같아서',
#   '그만둠',
#   '웃기',
#   '싫은데도',
#   '웃겨서',
#   '끈거',
#   '임',
#   'ㅇㅇ'],
#  ['내', '뜰거라고', '했지', '근데', '아니라', '였던거에요', '눈물', '났어요'],
#  ['언어',
#   '압박',
#   '심한',
#   '입니다',
#   '생각',
#   '보다',
#   '어렵고',
#   '재미',
#   '그다지',
#   '못',
#   '느끼는',
#   '이라고',
#   '생각',
#   '합니다'],
#  ['훌륭한', '작품', '입니다', '단점', '스토리', '짧습니다', '장점', '역시', '툼레이더', '입니다'],
#  ['재미', '있는데', '사람', '없다'],
#  ['조', '작', '감', '좋지', '못', '해요'],
#  ['어떤',
#   '원해서',
#   '구매',
#   '하는지',
#   '잘',
#   '알것',
#   '같은데',
#   '이건',
#   '어떤',
#   '식',
#   '으로',
#   '든',
#   '그',
#   '보다',
#   '못',
#   '한',
#   '일',
#   '겁니다',
#   '노잼',
#   '세',
#   '일',
#   '하더라도',
#   '구매',
#   '하지',
#   '않는',
#   '것',
#   '좋다고',
#   '생각',
#   '합니다'],
#  ['재미있어용', '와우'],
#  ['첫',
#   '엔딩',
#   '노멀',
#   '봤는데',
#   '재밌게',
#   '했습니다',
#   '플레이',
#   '타임',
#   '비록',
#   '짧지만',
#   '확',
#   '빠져',
#   '드',
#   '네'],
#  ['로켓',
#   '조종',
#   '해서',
#   '무사히',
#   '착륙시키는',
#   '이래',
#   '뵈도',
#   '어렵다만',
#   '폭팔',
#   '하는',
#   '이펙트',
#   '의외로',
#   '멋있음',
#   '난',
#   '무료',
#   '행사',
#   '때',
#   '얻음'],
#  ['세상', '에서', '제일', '아까운', '분이었습니다'],
#  ['시간', '이면', '평가', '해도', '돼요', '아님', '더하고와'],
#  ['타', '격감', '히오스', '보다', '좋음'],
#  ['처음', '엔', '컨텐츠', '없는줄', '알았다가', '하면', '할', '수록', '할게', '많은'],
#  ['아니',
#   '발',
#   '내는건',
#   '좋은데',
#   '없어도',
#   '할',
#   '수',
#   '있게',
#   '발매',
#   '해야',
#   '될거아냐',
#   '같네',
#   '진짜',
#   '가격',
#   '존나',
#   '게',
#   '비싸면서',
#   '기능',
#   '창작',
#   '마당',
#   '보다도',
#   '못',
#   '하고',
#   '빙융',
#   '시',
#   '시',
#   '인색',
#   'ㄱㄱ',
#   '긱들'],
#  ['삶은',
#   '서로',
#   '죽',
#   '이며',
#   '살아간다',
#   '자연',
#   '과',
#   '인간',
#   '잔혹함을',
#   '새로운',
#   '관점',
#   '에서',
#   '바라보는'],
#  ['던파', '충', '들', '해', '라'],
#  ['가성', '비', '최고', '입니다', '친구', '들', '이랑', '즐기기', '좋습니다'],
#  ['임',
#   '다운',
#   '받았는데',
#   '실행',
#   '안되요',
#   '다이렉트',
#   '문제',
#   '실행',
#   '안되서',
#   '다이렉트',
#   '재',
#   '설치',
#   '하고',
#   '최신',
#   '버젼',
#   '으로',
#   '해봤는데',
#   '소용없네요',
#   '들어가다',
#   '팅깁니다'],
#  ['서버', '사람', '없음', '중국', '인들', '때매', '접은듯'],
#  ['병맛', '으로', '하는', 'ㅋㅋㄱ', '가격', '비해', '개꿀'],
#  ['멀티플레이', '만큼은', '배필', '급'],
#  ['예전',
#   '테마',
#   '병원',
#   '생각',
#   '하고',
#   '구입',
#   '했는데',
#   '와',
#   '잠깐',
#   '한다고',
#   '했는데',
#   '오후',
#   '시',
#   '시작',
#   '했는데',
#   '새벽',
#   '넘기고',
#   '있더라는',
#   '허허',
#   '허',
#   '추천',
#   '합니다',
#   '문상',
#   '으로',
#   '충전',
#   '해서',
#   '사세요'],
#  ['사이버', '멀미', '느끼고', '싶다면', '추천', '여러가지', '해봤지만', '처음', '이다'],
#  ['진짜',
#   'ㄹㅇ',
#   '꿀잼',
#   '거',
#   '하다',
#   '보면',
#   '시간',
#   '가는줄',
#   '모름',
#   '모드',
#   '까지',
#   '깔아서',
#   '하면',
#   '꿀잼'],
#  ['찬란히',
#   '빛나는',
#   '남자',
#   '상징',
#   '그',
#   '길고',
#   '짧은',
#   '여정',
#   '개뿔',
#   '바바리맨',
#   '안',
#   '잡히기',
#   '놀이',
#   '겜'],
#  ['재밌음',
#   '버그',
#   '없어지고',
#   '중세시대',
#   '좋아한다면',
#   '한번',
#   '쯤',
#   '해볼만',
#   '함',
#   '처음',
#   '나올',
#   '때',
#   '버그',
#   '제대로',
#   '고쳐서',
#   '나왔었으면',
#   '좋았었을텐데'],
#  ['지금',
#   '해도',
#   '꿀잼',
#   '인데',
#   '지금',
#   '해도',
#   '멀미',
#   '남',
#   '으아',
#   '못',
#   '하게',
#   '썽',
#   'ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ'],
#  ['쩌',
#   '입니다',
#   '꼭',
#   '해보세요',
#   '이상',
#   '자세한',
#   '설명',
#   '생략',
#   '한다',
#   '왜',
#   '냐',
#   '고요',
#   '스포일러',
#   '거든'],
#  ['부모님',
#   '보여',
#   '드렸더니',
#   '아주',
#   '좋아하십니다',
#   '근데',
#   '어머니',
#   '고래',
#   '무서워서',
#   '중간',
#   '포기',
#   '하',
#   '심',
#   '크긴',
#   '크더라고요',
#   'ㅎㅎ',
#   '물고기',
#   '건드리면',
#   '도망가고',
#   '말미잘',
#   '건드리면',
#   '숨어',
#   '버립니다',
#   '접대',
#   '용',
#   '으로',
#   '좋아서',
#   '환불',
#   '않고',
#   '계속',
#   '가지',
#   '고',
#   '있을',
#   '생각',
#   '이네',
#   'ㅋㅋ'],
#  ['전작',
#   '개띵작이었',
#   '지만',
#   '망했다',
#   '물론',
#   '후속작',
#   'ㅈ',
#   '망했다',
#   '사지마라',
#   '걍',
#   '차라리',
#   '복돌',
#   '해',
#   '라'],
#  ['내', '원하는', '노래', '리듬게임', '할수가있다', '걸', '대', '만족'],
#  ['꺼져라', '고', '인물', '쉑들'],
#  ['저', '반값', '구매', '했습니다'],
#  ['프레임',
#   '고정',
#   '으로',
#   '계속',
#   '나오는데',
#   '자체',
#   '문제',
#   '계속',
#   '조금씩',
#   '버벅',
#   '이고',
#   '끊김',
#   '그래픽',
#   'ㅈ',
#   '구림'],
#  ['아니',
#   '왜',
#   '키안',
#   '주고',
#   '난리',
#   '시발',
#   '어떻',
#   '게',
#   '하',
#   '라고',
#   '먼저',
#   '구매',
#   '한',
#   '사람',
#   '호갱',
#   '댓',
#   '구연'],
#  ['장기', '에프', '가슴', '털'],
#  ['실행', '안되', '좃망겜'],
#  ['친구', '들', '이랑', '같이', '하면', '재미있는데', '멀미', '심해서', '오래', '못', '하겠음'],
#  ['얼엑', '으로', '내놓고', '개발', '중단', '먹튀'],
#  ['허무함', '주인공', '그', '특유', '인생', '혼자', '산', '허세', '말투', '짜증남', 'ㅋㅋㅋㅋ'],
#  ['네',
#   '코파',
#   '라',
#   '엑스트라',
#   '시간',
#   '분량',
#   '분',
#   '으로',
#   '축약',
#   '한',
#   '애니매이션',
#   '입니다',
#   '비교',
#   '적',
#   '짧은',
#   '시간',
#   '이라',
#   '느긋하게',
#   '보실',
#   '수',
#   '있습니다',
#   '앤딩곡',
#   '좋아요',
#   '메이플',
#   '좋아'],
#  ['나가', '디지세요', '유저', '좆목질', '꼬', '라지', '뉴비', '배척', '오지', '겜'],
#  ['내', '인생', '최고', '생일', '선물'],
#  ['엣지', '보다', '훨', '좋다'],
#  ['업데이트',
#   '전',
#   '에는',
#   '오버',
#   '쿡',
#   '보다',
#   '쉽고',
#   '가면',
#   '갈수록',
#   '난이도',
#   '변동',
#   '없길래',
#   '많이',
#   '실망',
#   '하며',
#   '난이도',
#   '좀더',
#   '높게',
#   '나오면',
#   '좋겠다고',
#   '생각',
#   '했었는데',
#   '점수',
#   '대가',
#   '하나',
#   '추가',
#   '되면서',
#   '그래도',
#   '만족도',
#   '올라갔다',
#   '근데',
#   '점수',
#   '대가',
#   '에바',
#   '잖아'],
#  ['화면', '전환'],
#  ['전',
#   '쏘',
#   '쏘하게',
#   '했네요',
#   '시간',
#   '정도',
#   '즐겁게',
#   '했으면',
#   '이정',
#   '가격',
#   '만족합니다',
#   '다만',
#   '나중',
#   '되면',
#   '변수',
#   '거의',
#   '없어지고',
#   '습격',
#   '해오는',
#   '부족',
#   '들',
#   '만',
#   '강제',
#   '강하게',
#   '하는',
#   '느낌',
#   '강했어요',
#   '그',
#   '때',
#   '부터',
#   '재미',
#   '확',
#   '떨어지니',
#   '뭔가',
#   '다른',
#   '방법',
#   '추가',
#   '해야',
#   '할',
#   '것',
#   '같습니다'],
#  ['웰',
#   '메이드',
#   '플랫포머',
#   '조작',
#   '감',
#   '브금',
#   '액션',
#   '맵',
#   '구성',
#   '스토리',
#   '개인',
#   '적',
#   '으로',
#   '전부',
#   '맘',
#   '들었음',
#   '옛날',
#   '닌자',
#   '덴',
#   '과',
#   '매우',
#   '비슷한데',
#   '상위호환',
#   '이라고',
#   '볼',
#   '수',
#   '있음',
#   '어릴',
#   '적',
#   '페미',
#   '컴',
#   '향수',
#   '느끼고',
#   '싶은',
#   '사람',
#   '들',
#   '필',
#   '구해',
#   '야할'],
#  ['재밌당', '고', '인물', '많당', '접어야겠당'],
#  ['빠요', '엔', '많음'],
#  ['정말로', '잼있어요', '친구', '하면', '잼있다'],
#  ['울', '삼촌', '빠진', '겜', '근데', '난', '노잼'],
#  ['재밌으나', '다른사람', '들', '하다가', '멘탈', '나가는거', '보는건', '꿀잼'],
#  ['상당히', '지루한', '오픈월드'],
#  ['재밌긴한데',
#   '범인',
#   '추론',
#   '하는',
#   '과정',
#   '억지',
#   '임',
#   '증거',
#   '없이',
#   '추론',
#   '만으로',
#   '범인',
#   '잡는게',
#   '위험하지',
#   '않나싶음'],
#  ['남자', '로망'],
#  ['노잼',
#   '인데',
#   '팀',
#   '포의',
#   '코믹',
#   '스러',
#   '움',
#   '따라하고',
#   '싶었나',
#   '본데',
#   '팀',
#   '포의',
#   '코믹',
#   '함',
#   '캐릭터',
#   '익숙함이',
#   '큰',
#   '바탕',
#   '이루고',
#   '있어서',
#   '흉측하고',
#   '잔인할',
#   '뿐인',
#   '캐릭터',
#   '와',
#   '연출',
#   '로는',
#   '절대',
#   '안',
#   '될',
#   '듯'],
#  ['이다', '변한', '거', '없다', '들', '도망쳐'],
#  ['재미없음',
#   '처음',
#   '에는',
#   '오',
#   '헬기',
#   '드론',
#   '탱크',
#   '드론',
#   '이런거',
#   '조종',
#   '해서',
#   '나름',
#   '괜찼',
#   '싶었는데',
#   '하면',
#   '할',
#   '수록',
#   '재미',
#   '없어짐',
#   '헬기',
#   '딱',
#   '번',
#   '등장',
#   '함',
#   '탱크',
#   '반',
#   '이고',
#   '컴퓨터',
#   '아군',
#   '전혀',
#   '도움',
#   '안됨',
#   '걸',
#   '왜',
#   '하는지',
#   '모르겠음',
#   '묶음',
#   '떨이',
#   '해서',
#   '샀는데',
#   '엉',
#   '아님'],
#  ['아', '제작자', '버린'],
#  ['꿀잼', '이지만', '사람', '없다', '멀티', '하는게', '매우', '힘듬'],
#  ['사양', '가격', '이런', '구', '하기', '어렵습니다', '이건', '꼭', '사세요'],
#  ['모든',
#   '도전',
#   '과제',
#   '완료',
#   '성공한',
#   '킥스타터',
#   '중',
#   '하나',
#   '인',
#   '웨이스트랜드',
#   '클래식',
#   '한',
#   '서양',
#   '알피',
#   '지',
#   '장르',
#   '좋아한다면',
#   '꼭',
#   '해봐야',
#   '합니다',
#   '물론',
#   '아쉬운',
#   '점도',
#   '있지만'],
#  ['음',
#   '걍',
#   '공짜',
#   '라는',
#   '것',
#   '갓',
#   '겜',
#   '인데',
#   '재미',
#   '있슴',
#   '쫄보',
#   '하지마',
#   '셈',
#   '존시나',
#   '무서움'],
#  ['다른',
#   '과',
#   '차별',
#   '화',
#   '둔게',
#   '있다면',
#   '그건',
#   '에는',
#   '점프',
#   '없다는',
#   '것',
#   '이다',
#   '생존',
#   '겜',
#   '인데'],
#  ['엉',
#   '성한',
#   '컷씬',
#   '지루한',
#   '전투',
#   '사이드',
#   '퀘스트',
#   '부족',
#   '다른',
#   '지역',
#   '퀘스트',
#   '따라서',
#   '갈수',
#   '있으나',
#   '퀘스트',
#   '깬',
#   '후',
#   '에는',
#   '가지',
#   '못',
#   '하는',
#   '지역',
#   '존재',
#   '컷씬',
#   '장면',
#   '에서',
#   '주인공',
#   '이유',
#   '없는',
#   '얼굴',
#   '검은',
#   '칠',
#   '등',
#   '차',
#   '플레이',
#   '하고',
#   '싶지',
#   '않는',
#   '입니다'],
#  ['어렵습니다', '재밌습니다'],
#  ['서든'],
#  ['좆',
#   '같이',
#   '만',
#   '드',
#   '네',
#   '시발',
#   '멀티',
#   '해보자',
#   '할',
#   '때',
#   '마다',
#   '팅겨',
#   '개',
#   '같은'],
#  ['게끝'],
#  ['맨', '탈', '박살', '남'],
#  ['개답답', '씹', '노잼', '트레일러', '낚임'],
#  ['진짜',
#   '액션',
#   '성',
#   '플',
#   '래',
#   '이타입',
#   '바뀐거',
#   '참고',
#   '해볼려',
#   '해도',
#   '번역',
#   '떄매',
#   '진짜',
#   '하기',
#   '싫어진다'],
#  ['내', '왜', '샀을까', '지금', '까지', '산', '중', '가장', '최악', '이다'],
#  ['한',
#   '키',
#   '보드',
#   '두',
#   '명',
#   '서',
#   '할수',
#   '있는데',
#   '사고싶으면',
#   '사든가',
#   '뭐',
#   '원',
#   '이라서',
#   '샀지만'],
#  ['출시', '된', '지', '년', '지났지만', '지금', '있어', '넘어서는', '멀티플레이어', '없다'],
#  ['재미있고', '좋은데', '한글', '번역', '할꺼면', '제대로', '해주세요'],
#  ['하고', '구매', '결심', '하게', '됐습니다', '고마워요', '네', '코파', '라', '이브'],
#  ['트럼프', '이나', '수술', '해드립시다'],
#  ['스텐리', '재밌게', '했으면', '재밌게', '할만', '함'],
#  ['재밌다', '팬심', '으로', '한', '듯'],
#  ['와', '내', '해본', '퍼즐', '중', '제일', '어렵다'],
#  ['지', '원안', '하고', '랑', '만', '지', '원함', '화질', '극', '혐', '화', '면', '짤림'],
#  ['거', '로그인', '안되는군요', '이름', '짓기', '힘듬'],
#  ['오크',
#   '관리',
#   '하는',
#   '시스템',
#   '지나칠',
#   '정도',
#   '분량',
#   '많음',
#   '개',
#   '지역',
#   '이상',
#   '점령',
#   '하는거',
#   '직접',
#   '했으면',
#   '오크',
#   '성애자',
#   '임'],
#  ['실행',
#   '함',
#   '과',
#   '동시',
#   '렉',
#   '걸립니다',
#   '그런데',
#   '웃긴',
#   '것',
#   '정작',
#   '본',
#   '켐페인',
#   '들어가면',
#   '렉',
#   '걸리지가',
#   '않습니다',
#   '메인',
#   '화면',
#   '에서',
#   '렉',
#   '걸리지',
#   '않게',
#   '해주세요',
#   '사고',
#   '나서',
#   '정낙',
#   '못',
#   '하고',
#   '있습니다',
#   'ㅠㅠ'],
#  ['아니', '게', '안되네', '아니', '게', '되네'],
#  ['내', '헤봤을때', '현질', '유저', '들', '뉴비', '학살', '하는', '장면', '보았는데', '존나', '미쳤다'],
#  ['무섭고', '재미', '없다', '마지막', '엔', '짜증', '만', '가득'],
#  ['음',
#   '돈',
#   '벌려고',
#   '만든',
#   '아니네',
#   '잘',
#   '만들긴',
#   '했는데',
#   '뭔가',
#   '아니다',
#   '싶네',
#   '자기',
#   '맘',
#   '들게',
#   '만들면',
#   '되는거지',
#   '뭐',
#   '까지',
#   '찍는',
#   '동안',
#   '재밋',
#   '게',
#   '잘',
#   '했어요',
#   '나중',
#   '컨텐츠',
#   '추가',
#   '되면',
#   '그때',
#   '다시',
#   '봐요'],
#  ['어려운거', '빼고', '좋은', '만드시느라', '고생', '하', '셧읍니'],
#  ['구림'],
#  ['서버',
#   '관리',
#   '안됩니다',
#   '피',
#   '씨방',
#   '에서',
#   '접속',
#   '해도',
#   '렉',
#   '기본',
#   '이고',
#   '튕',
#   '기기',
#   '까지',
#   '하니',
#   '힘드네요'],
#  ['운수', '좋은', '날일', '때', '하세요', '친구', '랑', '하면', '재미있습니다', '친구', '없다고요'],
#  ['현재', '시간', '가량', '플레이', '중', '입니다', '네', '시간', '동안', '못', '잤습니다'],
#  ['왜', '멀미', '나냐'],
#  ['뭐', '할게', '없어요'],
#  ['진', '엔딩', '봤으니깐', '하는', '말', '인데', '프롬', '시발', '놈', '들', '아', '게', '이냐'],
#  ['특이점', '누르면', '후회', '함'],
#  ['환불', '안', '해주면', '박현준'],
#  ['할', '겜', '없을', '때', '하려고', '샀는데', '이거하느라', '다른', '겜', '접음'],
#  ['사람', '없다', '혼자', '하면', '재미', '없음', '스토리', '없음', '삭제', '걸', '설명', '끝'],
#  ['컨텐츠', '얼마', '없고', '할거', '없어요'],
#  ['내', '로그라이크', '모드', '어디', '갔는데'],
#  ['한국어', '패치', '버전', '없다는게', '가장', '아쉽습니다', '한글패치', '꼭좀', '나왔으면', '좋겠습니다'],
#  ['제발', '젠', '챕', '터좀', '주세요', 'ㅠㅠ'],
#  ['낙지', '볶음', '시뮬레이터', '개꿀잼', '내', '인생'],
#  ['충성', '충성', '싸', '돌아다니기', '좋아하면', '갓', '겜'],
#  ['이런', '류', '캐', '쥬얼', '좋아하는데', '후속작', '없는', '건가', 'ㅠ'],
#  ['재밌긴',
#   '한데',
#   '가장',
#   '큰',
#   '문제',
#   '컨텐츠',
#   '한정',
#   '적',
#   '이라는',
#   '점',
#   '이다',
#   '계속',
#   '똑같은',
#   '거만',
#   '하게',
#   '되고',
#   '금방',
#   '질리',
#   '게',
#   '되는',
#   '단점',
#   '있다',
#   '혹시',
#   '사실',
#   '분이라면',
#   '딱히',
#   '안',
#   '하는게',
#   '낫다',
#   '점',
#   '말씀드리고',
#   '싶다'],
#  ['재미', '있는데', '도전', '과제', '사람', '찝찝하게', '만드', '네'],
#  ['좀비',
#   '사칙연산',
#   '하는',
#   '머리',
#   '좋아지는',
#   '느낌이네요',
#   '팁',
#   '기호',
#   '나누기',
#   '입니다',
#   '거땜',
#   '난이도',
#   '급상승'],
#  ['권총', '쏘는', '재미', '하나', '원', '탑', '이다', '말', '이야'],
#  ['한', '턴', '만', '분만', '한', '시간', '만', '하루', '만'],
#  ['엔딩', '조건', '빼고는', '전작', '이랑', '뭐', '달리진거야'],
#  ['그래픽', '성', '뭐', '하나', '빠지지', '않는', '쓰레기', '이네'],
#  ['오른쪽',
#   '팔이',
#   '펌핑',
#   '되었다',
#   '마우스',
#   '회사',
#   '에서',
#   '마우스',
#   '전부',
#   '파괴',
#   '하려고',
#   '만든',
#   '프로그램',
#   '인가',
#   '보다',
#   '원래',
#   '마우스',
#   '클릭',
#   '횟수',
#   '수명',
#   '아니냐',
#   '아',
#   '팔',
#   '아',
#   '파도전',
#   '과제',
#   '순식간',
#   '클리어',
#   '한',
#   '건',
#   '좋다'],
#  ['개', '좋음'],
#  ['바탕화면', '꾸미기에', '아주', '좋음'],
#  ['아',
#   '진짜',
#   '컨베이어',
#   '벨트',
#   '깔다가',
#   '각종',
#   '방향',
#   '버그',
#   '시스템',
#   '작동시킬려면',
#   '온갖',
#   '오류',
#   '넘치는데',
#   '빡쳐서',
#   '접는다'],
#  ['멍청해서', '싫다'],
#  ['차라리', '유로', '트럭', '하세요'],
#  ['프레임', '드랍', '심함'],
#  ['다듬어야', '할게', '많음', '타', '격감', '이나', '탄', '속', '버그', '등'],
#  ['퍼즐',
#   '좋은데',
#   '터',
#   '무니',
#   '없는',
#   '곳',
#   '에서',
#   '퍼즐',
#   '조각',
#   '들',
#   '나온다',
#   '막혔다',
#   '싶으면',
#   '무작정',
#   '더블클릭',
#   '해보면',
#   '확대',
#   '되면서',
#   '예',
#   '상치',
#   '못',
#   '한',
#   '곳',
#   '있거나',
#   '렌즈',
#   '무조건',
#   '써',
#   '봐',
#   '야한다'],
#  ['무료', '체험판', '해봤는데', '잘', '만들었는데', '못', '사겠네요', '잘', '만들어서', '무서워', 'ㅜㅜ'],
#  ['단점',
#   '강제',
#   '적',
#   '으로',
#   '보여주는',
#   '컷신',
#   '많음',
#   '플레이',
#   '분도',
#   '안되서',
#   '보이는',
#   '캐릭터',
#   '부자연스러운',
#   '움직임',
#   '더러운',
#   '조작',
#   '감',
#   '장점',
#   '모든',
#   '걸',
#   '분도',
#   '안되서',
#   '느낄',
#   '수',
#   '있어서',
#   '환불',
#   '결정',
#   '빠름'],
#  ['오픈월드',
#   '에서',
#   '경찰',
#   '과',
#   '도둑',
#   '하는',
#   '굴잼',
#   '인데',
#   '커스터',
#   '마',
#   '이징도',
#   '무궁무진',
#   '하고',
#   '좋은데',
#   '망친',
#   '이유',
#   '운영',
#   '망쳤습니다',
#   '페이',
#   '투윈',
#   '고',
#   '인물',
#   '많음',
#   '개인',
#   '적',
#   '으로',
#   '이런',
#   '느낌',
#   '오픈월드',
#   '또',
#   '나왔으면',
#   '좋겠',
#   '읍니'],
#  ['고대',
#   '전투',
#   '재현',
#   '하다는',
#   '본래',
#   '재미',
#   '여전하다',
#   '내정',
#   '이라고',
#   '할만',
#   '한',
#   '것',
#   '없어서',
#   '반복',
#   '전투',
#   '지겨워질',
#   '때',
#   '매력',
#   '하는',
#   '느낌',
#   '이다'],
#  ['아쉬워요'],
#  ['것', '바로', '시간', '거', '스르', '자'],
#  ['어우', '중국', '발', '미세먼지', '더럽히네', '착', '짱', '죽', '짱', '진리'],
#  ['흠',
#   '현실',
#   '성',
#   '굉장히',
#   '뛰어나고',
#   '흔',
#   '근',
#   '히',
#   '세력',
#   '대한',
#   '감정',
#   '싸움',
#   '물론',
#   '특히',
#   '일본',
#   '과',
#   '우리나라',
#   '감정',
#   '싸움',
#   '특히',
#   '매우',
#   '가합니다',
#   '그런',
#   '걸',
#   '까요',
#   '아니면',
#   '완성',
#   '굉장히',
#   '높아서',
#   '그런거',
#   '일까',
#   '매우',
#   '재미있습니다'],
#  ['네', '코파', '라', '시리즈', '스팀', '야겜', '필수', '목록', '순위', '입니다'],
#  ['뭔가', '깨기', '어렵'],
#  ['몰러', '배그', '보다', '재밌당', '헤헿'],
#  ['여우', '새끼', '어딨는거야'],
#  ['리듬게임', '인데', '리듬', '맞지', '않는', '신기', '한게임'],
#  ['싱글플레이',
#   '방방',
#   '뛰면서',
#   '연속',
#   '킬',
#   '딸때',
#   '쾌감',
#   '진짜',
#   '인정',
#   '타임',
#   '어택',
#   '그래도',
#   '속',
#   '도감',
#   '속',
#   '도감',
#   '인지',
#   '라',
#   '도전',
#   '욕구',
#   '생겼었다',
#   '그래',
#   '생겼었지',
#   '야',
#   '발',
#   '멀티플레이',
#   '안',
#   '해봄'],
#  ['배경음악', '굿'],
#  ['만', '오른쪽', '컨트롤', '키', '없어서', '못', '함'],
#  ['웜',
#   '커엽',
#   '근데',
#   '도움말',
#   '없고',
#   '길찾기',
#   '넘',
#   '힘듬',
#   '퀘스트',
#   '깨는것보다',
#   '찾으러',
#   '돌아다니는게',
#   '시간',
#   '더듬'],
#  ['처음', '목맨', '남자', '애', '보고있으면', '눈뜸'],
#  ['솔직하게',
#   '미연시',
#   '작품',
#   '그리',
#   '잘',
#   '하지를',
#   '않는데',
#   '네',
#   '코파',
#   '라',
#   '사쿠라',
#   '스피릿',
#   '등',
#   '모두',
#   '시간',
#   '것',
#   '만큼은',
#   '진짜',
#   '명작',
#   '같았다',
#   '처음',
#   '으로',
#   '미연시',
#   '라는',
#   '장르',
#   '빠져든',
#   '작품',
#   '였다'],
#  ['세이브',
#   '파일',
#   '스팀',
#   '클라우드',
#   '동기화',
#   '안되는데',
#   '그것',
#   '만',
#   '어떻게',
#   '처리',
#   '된다면',
#   '괜찮을거',
#   '같아요',
#   '스토리',
#   '진행',
#   '하는데',
#   '영어',
#   '딸려서',
#   '시간',
#   '정도',
#   '걸리네요',
#   '분량',
#   '조금',
#   '짧은',
#   '느낌',
#   '들었고',
#   '급전',
#   '개',
#   '라는',
#   '느낌'],
#  ['무서웠습니다', '후', '덜덜', '간이', '커지면', '다시', '해보겠습니다'],
#  ['쟝게파'],
#  ['영어', '알아야', '재밌다', '구린', '아님', '좋음'],
#  ['컨텐츠', '없네'],
#  ['사람', '없다'],
#  ['비추',
#   '합니다',
#   '오픈',
#   '첫날',
#   '주말',
#   '내내',
#   '서버',
#   '닫아',
#   '두는',
#   '기술',
#   '력',
#   '감탄',
#   '하고',
#   '갑니다'],
#  ['옛날', '많이', '했었는데', '다시', '해보니까', '여전히', '재밌었습니다'],
#  ['길', '찾다', '개', '빡치네', '길치랑', '성격', '급한', '사람', '하지말길'],
#  ['한',
#   '놈',
#   '몰',
#   '빵',
#   '해서',
#   '키우다가',
#   '죽으면',
#   '멘탈',
#   '검투사',
#   '대가리',
#   '날라가듯이',
#   '날라',
#   '감'],
#  ['암', '워킹', '인더', '레인'],
#  ['망겜', '이라', '그리', '말', '했거늘', '어떤', '초딩', '부들부들', '거리', '면서', '비추를', '눌렀는가'],
#  ['강렬한', '네온사인', '눈', '멀어', '버렸습니다'],
#  ['서로', '죽', '이며', '지랄', '하는'],
#  ['탭키',
#   '유저',
#   '정보',
#   '보면',
#   '항상',
#   '열',
#   '네다섯',
#   '명',
#   '애니',
#   '프사',
#   '달고있는',
#   '씹덕',
#   '들',
#   '어디',
#   '서나',
#   '한글',
#   '만',
#   '고집',
#   '하며',
#   '외국인',
#   '당당하게',
#   '한글',
#   '대화',
#   '하려하는',
#   '코충',
#   '캐',
#   '주얼',
#   '에서도',
#   '눕스거리',
#   '며',
#   '뉴비',
#   '배척',
#   '정치',
#   '질하는',
#   '고이',
#   '못',
#   '해',
#   '썩은',
#   '물들',
#   '완죤',
#   '뭐',
#   '하나',
#   '빠진',
#   '것',
#   '없이',
#   '완벽한',
#   '갓',
#   '겜',
#   '이자',
#   '너'],
#  ['나쁘진', '않은데', '엔딩', '꼭', '그렇게만', '했어야', '했는지가', '의문'],
#  ['인원',
#   '라는',
#   '점',
#   '조금',
#   '아쉬운것',
#   '빼고는',
#   '좋음',
#   '약간',
#   '어설픈',
#   '그래픽',
#   '과',
#   '쓸데없는',
#   '디테일',
#   '들',
#   '거꾸로',
#   '매력',
#   '포인트',
#   '임'],
#  ['공략',
#   '봐도',
#   '어렵네요',
#   '초반',
#   '부터',
#   '이러면',
#   '후반',
#   '에선',
#   '어떨지',
#   '두려워서',
#   '끝',
#   '까지',
#   '못',
#   '하겠습니다'],
#  ['이제',
#   '당신',
#   '년',
#   '미국',
#   '만들',
#   '수',
#   '있습니다',
#   '물론',
#   '건너편',
#   '중국',
#   '거대해진',
#   '건',
#   '예',
#   '외지',
#   '만'],
#  ['어려웠지만',
#   '이런',
#   '겜',
#   '좋아한',
#   '터',
#   '라',
#   '넘나',
#   '잼있습니다',
#   '이런',
#   '겜',
#   '또',
#   '있었으면',
#   '좋겠네요'],
#  ['서버', '어디', '감', '미아', '엉엉'],
#  ['처음',
#   '시작',
#   '하',
#   '면',
#   '화면',
#   '회색',
#   '입니다',
#   '회색',
#   '화면',
#   '돌아다녀',
#   '봤는데',
#   '산이',
#   '랑',
#   '들이랑',
#   '네',
#   '여',
#   '돌아다니면서',
#   '경치',
#   '구경',
#   '하는',
#   '인',
#   '것',
#   '같은데',
#   '일단',
#   '추천',
#   '누릅니다',
#   '아직',
#   '개발',
#   '이라',
#   '그런것',
#   '같아요',
#   'ㅋㅋ',
#   '좀더',
#   '개발',
#   '되면',
#   '해봐야',
#   '겠어요'],
#  ['레디', '하는', '법좀', '알려줘요', 'ㅠㅠ', '제발'],
#  ['오',
#   '거',
#   '쫌',
#   '만',
#   '추가',
#   '할꺼',
#   '추가',
#   '하면',
#   '재밌을',
#   '듯',
#   '개뿔',
#   '좋게',
#   '쓰자마자',
#   '서버',
#   '무한',
#   '로딩'],
#  ['버그', '심하고', '힘듭니다'],
#  ['기분',
#   '좋게',
#   '한글',
#   '플레이',
#   '해서',
#   '즐거웠습니다',
#   '플레이',
#   '마지막',
#   '쯤',
#   '설마',
#   '걸',
#   '끝일',
#   '까',
#   '라는',
#   '생각',
#   '많이',
#   '하게',
#   '됐는데',
#   '정말로',
#   '끝나더군요',
#   '볼륨',
#   '아쉽지만',
#   '전체',
#   '적',
#   '으로',
#   '만족했습니다'],
#  ['재미', '있어서', '플레이', '하는데', '난데없이', '잠수', '강퇴', '당했다', '킁', '좆목질', '노답'],
#  ['애초',
#   '사고',
#   '깔아서',
#   '할려고',
#   '하는데',
#   '실해',
#   '오류',
#   '라면',
#   '서',
#   '실행',
#   '조차',
#   '않',
#   '됌'],
#  ['아니',
#   '아무',
#   '것',
#   '않',
#   '했는데',
#   '무슨',
#   '타사',
#   '소프트웨어',
#   '썻다',
#   '고',
#   '년',
#   '정지',
#   '야',
#   'ㅈ',
#   '망겜'],
#  ['뭐', '이런', '허', '졉', '한게임', '난생', '첨으로', '이렇게', '조작', '조잡한', '처음'],
#  ['저화질',
#   '비',
#   '한글',
#   '입니다',
#   '짧지',
#   '않은',
#   '편',
#   '인데',
#   '숨은그림찾기',
#   '장면',
#   '넘',
#   '짜증나요',
#   '웬만하면',
#   '다른',
#   '유명한',
#   '들',
#   '추천',
#   '합니다'],
#  ['게속', '에러', '떠서', '실행', '안됨', '사양', '되는', '데도'],
#  ['해봐야', '알', '것', '같아요'],
#  ['석상', '안나옵니다'],
#  ['고',
#   '인물',
#   '잔뜩',
#   '인',
#   '건',
#   '그렇다고',
#   '치고',
#   '최소한',
#   '서버',
#   '관리',
#   '해줘',
#   '나온지',
#   '얼마나',
#   '지났는데',
#   '상대',
#   '멀쩡하게',
#   '푱푱푱',
#   '잘만',
#   '쌓는데',
#   '만',
#   '블록',
#   '생',
#   '성',
#   '초',
#   '정도',
#   '걸림',
#   '뭐',
#   '지',
#   '재네는',
#   '공장',
#   '에서',
#   '블록',
#   '찍어내고',
#   '수',
#   '작업',
#   '으로',
#   '만들어내는것도',
#   '아니고'],
#  ['이고', '리', '로딩', '하는', '법', '안', '알려줘서', '환불', '합니다'],
#  ['옛날',
#   '하던',
#   '포켓몬스터',
#   '같은',
#   '이다',
#   '엔딩',
#   '두',
#   '개',
#   '고',
#   '재밌긴',
#   '힌데',
#   '거',
#   '만든',
#   '새끼',
#   '정신',
#   '세계',
#   '궁금하다'],
#  ['핵', '존나', '많아', '투표', '기능', '비', '활성화', '되있고', '하지마', '셈'],
#  ['전작',
#   '결말',
#   '굉장히',
#   '난해하게',
#   '끝나서',
#   '찜찜했는데',
#   '그',
#   '찜찜함을',
#   '해소',
#   '시키는',
#   '게',
#   '아닌',
#   '배',
#   '시키는',
#   '듯',
#   '한',
#   '느낌',
#   '결국',
#   '또',
#   '같은',
#   '적',
#   '과',
#   '같은',
#   '분위기',
#   '와',
#   '같은',
#   '전투',
#   '데자뷰',
#   '처럼',
#   '반복',
#   '하는',
#   '건',
#   '절대',
#   '사양',
#   '하고',
#   '싶다'],
#  ['재밌습니다', '편이', '나와서', '그렇지'],
#  ['아',
#   '레이싱',
#   '제',
#   '환불',
#   '웬만해서',
#   '안',
#   '하는데',
#   '파나텍',
#   '에서',
#   '포스',
#   '피드백',
#   '전혀',
#   '느껴지지',
#   '않으며',
#   '모션',
#   '피드백',
#   '음',
#   '네',
#   '사지',
#   '마세요',
#   '프레임',
#   '프레임',
#   '돈',
#   '까지',
#   '덤',
#   '으로',
#   '줘도',
#   '안',
#   '갖을'],
#  ['운빨망겜', '능지', '부족', '망겜', '자신', '운빨', '과', '능지', '테스트', '할', '수', '있습니다'],
#  ['시간', '플레이', '동안', '요정', '한번', '안', '나왔다', '갓', '이다'],
#  ['하', '걸', '뭐라고', '해야되', '사지마라'],
#  ['골수',
#   '팬심',
#   '으로써',
#   '플레이',
#   '와',
#   '커버',
#   '에도',
#   '한계',
#   '있는',
#   '법',
#   '번작',
#   '이미',
#   '포기',
#   '한지',
#   '오',
#   '래지',
#   '만',
#   '곧',
#   '나오는',
#   '사',
#   '쇼',
#   '신작',
#   '그래픽',
#   '보고',
#   '다음',
#   '기대할만',
#   '한',
#   '가치',
#   '생겼습니다',
#   '그러니',
#   '하지말고',
#   '나오기를',
#   '기다릴',
#   '겁니다'],
#  ['잘',
#   '만들어',
#   '봐야',
#   '헬',
#   '조선',
#   '운영',
#   '얼마나',
#   '망칠수',
#   '있는지',
#   '보여주는',
#   '거기',
#   '아무리',
#   '봐도',
#   '운영',
#   '진',
#   '쪽바리'],
#  ['써버', '개판'],
#  ['할만',
#   '하긴한데',
#   '가사',
#   '있는',
#   '노래',
#   '대부분',
#   '중국어',
#   '대만어',
#   '고',
#   '리듬게임',
#   '인데',
#   '굳이',
#   '배경',
#   '번쩍번쩍',
#   '화려하게',
#   '만들',
#   '필요',
#   '있었나',
#   '싶음',
#   '눈',
#   '아프고',
#   '가시',
#   '성도',
#   '떨어짐'],
#  ['년도',
#   '때',
#   '나온',
#   '으론',
#   '이런',
#   '발상',
#   '최고',
#   '입니다',
#   '생존',
#   '최고',
#   '라',
#   '고도',
#   '생각',
#   '됩니다',
#   '다만',
#   '잦은',
#   '크래쉬',
#   '와',
#   '버그',
#   '단점',
#   '되고',
#   '특성',
#   '상',
#   '레벨',
#   '올리려는',
#   '욕심',
#   '불법',
#   '프로그램',
#   '사용',
#   '하는',
#   '유저',
#   '들',
#   '감점',
#   '됩니다'],
#  ['고', '렙', '과금', '충노', '닝겐'],
#  ['메'],
#  ['ㅈ', '같다'],
#  ['잡것', '들', '때문', '못', '해', '먹겠네'],
#  ['월',
#   '탱',
#   '보다야',
#   '블리츠',
#   '훨씬',
#   '훠',
#   '어어',
#   '어',
#   '얼씬',
#   '티어',
#   '올',
#   '리기',
#   '빠른데',
#   '것',
#   '마저도',
#   '무',
#   '과금',
#   '티어',
#   '가기',
#   '엔',
#   '상당히',
#   '많은',
#   '시간',
#   '소요',
#   '됨'],
#  ['여기', '들', '비슷해서', '무난', '하게', '플레이', '했지만', '이번', '건', '스토리', '별로', '였음'],
#  ['통해', '자신', '성', '정체', '성', '알아보는', '좋은', '시간', '만들어', '보아'],
#  ['비트'],
#  ['추울', '때', '창문', '열고', '하니', '현장', '감', '느껴지네요'],
#  ['한글화', '되서', '해봤는데', '내', '취향', '맞아서', '재밌게', '했', '읍니'],
#  ['인형', '편', '에서', '죽고', '귀신', '따라다니면', '좋은', '거', '규', '경', '가능'],
#  ['구', '버전', '깔아서', '하세요', '구', '버전', '맛', '살려야지'],
#  ['오픈월드', '형식', '퍼즐게임', '퍼즐게임', '좋아하는', '사람', '들', '추천', '함'],
#  ['많은', '의상', '필요합니다'],
#  ['실행',
#   '안됩니다',
#   '실행',
#   '클릭',
#   '하면',
#   '무',
#   '반응',
#   '스팀',
#   '에는',
#   '실행',
#   '중',
#   '으로',
#   '나오지만',
#   '아무런',
#   '창',
#   '뜨지',
#   '않습니다',
#   '작업',
#   '관리자',
#   '에서',
#   '서비스',
#   '들어가면',
#   '실행',
#   '중',
#   '인데',
#   '시작',
#   '안되네요'],
#  ['미래', '되지', '않기를'],
#  ['아주', '훌륭한', '소프트웨어', '창작', '마당', '만', '빼고'],
#  ['무료', '퍼즐게임', '이다', '할만', '한', '무료', '퍼즐게임'],
#  ['아주', '개', '적', '화가', '쩔어', '버림'],
#  ['난', '많은걸', '바라지', '않는다', '재밌는데', '멀미', '유발', '심해서', '오래', '못', '앉아있겠음'],
#  ['굴러도', '쳐', '맞네', '개시', '발'],
#  ['대다수',
#   '분',
#   '들',
#   '추천',
#   '하는',
#   '이나',
#   '별로',
#   '화면',
#   '아름답지만',
#   '만화',
#   '같고',
#   '이상하게',
#   '손맛',
#   '별로',
#   '결말',
#   '보려고',
#   '울며',
#   '겨자',
#   '먹기',
#   '꾸역꾸역',
#   '진행',
#   '하여',
#   '마지막',
#   '봤다',
#   '바이오쇼크',
#   '편도',
#   '하다가',
#   '때려',
#   '쳤는데',
#   '바이오쇼크',
#   '안',
#   '맞는',
#   '사람',
#   '에게는',
#   '별로',
#   '네'],
#  ['라이브러리', '묻히거라', '쿠소', '게'],
#  ['제품',
#   '표지',
#   '돼지',
#   '얼굴',
#   '과는',
#   '달리',
#   '인',
#   '에서의',
#   '돼지',
#   '얼굴',
#   '놀라우리만큼',
#   '순하게',
#   '생겼습니다'],
#  ['친구',
#   '와',
#   '함께하기에',
#   '좋은',
#   '한글화',
#   '걸고',
#   '넘어지는',
#   '사람',
#   '있는데',
#   '사실',
#   '없어도',
#   '알',
#   '아들',
#   '정도',
#   '되는',
#   '편'],
#  ['여러분', '언제', '스키', '익스트림', '하게', '타', '보겠습니까'],
#  ['세',
#   '모',
#   '덕',
#   '방송',
#   '보고',
#   '알았는데',
#   '생각',
#   '보다',
#   '재미있고',
#   '처',
#   '크의',
#   '표정',
#   '이나',
#   '몹',
#   '들',
#   '행동',
#   '들',
#   '귀여웠던'],
#  ['정신병'],
#  ['쓸고', '닦고', '정돈', '되는걸', '좋아한다면', '해볼', '만', '하지', '않을까요'],
#  ['아니',
#   '무슨',
#   '시',
#   '이발',
#   '조온나',
#   '아',
#   '실행',
#   '시키',
#   '기도',
#   '전',
#   '무슨',
#   '어류',
#   '뜨냐',
#   '만원',
#   '그녕',
#   '날려',
#   '먹었네'],
#  ['올해',
#   '월',
#   '쯤',
#   '공식',
#   '한글화',
#   '된다하네요',
#   '한글패치',
#   '만드시던',
#   '분',
#   '블로그',
#   '닫혀있고',
#   '전',
#   '관짝',
#   '으로',
#   '들어갑니다',
#   'ㅠㅠ'],
#  ['재밌어',
#   '게',
#   '재밌어',
#   '거',
#   '재밌다는',
#   '사람',
#   '들',
#   '넷마블',
#   '틀린',
#   '그림',
#   '찾기',
#   '해보셈',
#   '진짜',
#   '개',
#   '꿀잼'],
#  ['한때',
#   '인생게임',
#   '이었습니다',
#   '금요일',
#   '밤',
#   '시작',
#   '해서',
#   '밤새고',
#   '플레이',
#   '하기도',
#   '했고요',
#   '그렇지만',
#   '르귄',
#   '패치',
#   '이후',
#   '로는',
#   '도저히',
#   '할수가',
#   '어렵게',
#   '되었습니다',
#   '복잡',
#   '성',
#   '올라갔고',
#   '함대',
#   '대규모',
#   '편성',
#   '이나',
#   '유지',
#   '어려워지고',
#   '지워',
#   '버렸네요'],
#  ['게놈',
#   '아파',
#   '토사',
#   '우르',
#   '스',
#   '마리',
#   '부화',
#   '시키는',
#   '과학',
#   '미션',
#   '중이',
#   '였는데',
#   '게놈',
#   '아직',
#   '완성',
#   '못',
#   '했는데',
#   '발굴',
#   '지',
#   '고갈',
#   '뜨는건',
#   '무엇',
#   '버그',
#   'ㅈ',
#   '망겜'],
#  ['트라',
#   '인',
#   '시리즈',
#   '재밌어서',
#   '기대했는데',
#   '진심',
#   '하지',
#   '마세요',
#   '시리즈',
#   '중',
#   '마지막',
#   '인데',
#   '거',
#   '뭐',
#   '스토리',
#   '분도',
#   '안되서',
#   '꺠',
#   '고',
#   '진짜',
#   '스토리',
#   '형편',
#   '없음',
#   '진심',
#   '으로',
#   '덜',
#   '닦은',
#   '느낌',
#   '남',
#   '트',
#   '라인',
#   '시리즈',
#   '까지하세요'],
#  ['조', '작', '감', '부드러웠으면', '좋겠다'],
#  ['소개', '영상', '보고', '오신거', '압니', '근데', '그럴', '일', '없으실', '겁니다'],
#  ['불친절함',
#   '적',
#   '인',
#   '허용',
#   '으로',
#   '넘어갈거도',
#   '안',
#   '넘어가고',
#   '튜토리얼',
#   '과정',
#   '에서',
#   '뭐',
#   '문제',
#   '면',
#   '툴팁',
#   '으로',
#   '알려줘야지',
#   '그런거',
#   '하나',
#   '없음',
#   '환불',
#   '함'],
#  ['청소', '시작', '물', '쏟음', '멘붕', '재개', '또', '쏟음', '빡종'],
#  ['전작', '명성', '맞게', '확실히', '재밌는데', '전보', '어려워졌음', 'ㅠㅠ'],
#  ['재미',
#   '있지만',
#   '아군',
#   '지휘',
#   '관',
#   '보면',
#   '프래깅',
#   '왜',
#   '생겼는지',
#   '알것',
#   '같다',
#   '결국',
#   '혼자',
#   '서',
#   '마리',
#   '잡지',
#   '않으면',
#   '전선',
#   '유지',
#   '조차',
#   '안되고',
#   '아군',
#   '보이지',
#   '않는다',
#   '멍청한',
#   '멍청한',
#   '재미있다',
#   '와아',
#   '악'],
#  ['ㅈㄴ', '쓸', '때', '업어여', '사지', '마여'],
#  ['갑자기',
#   '겜',
#   '실행',
#   '전혀',
#   '안된다',
#   '오류',
#   '코드',
#   '인데',
#   '시바',
#   '뭐',
#   '문제',
#   '인지',
#   '진짜',
#   '좆망',
#   '겜',
#   '수준',
#   '어디',
#   '안',
#   '가는듯'],
#  ['왜', '플레이', '하면', '렉', '걸리지', '기술', '멋집니다', '급습', '멋집니다', '스토리', 'ㅁ'],
#  ['모바일',
#   '버전',
#   '과',
#   '플래시',
#   '버전',
#   '둘다',
#   '해봤음에도',
#   '불구',
#   '하고',
#   '오토',
#   '마우스',
#   '대체',
#   '미지',
#   '원',
#   '욕처',
#   '먹어도',
#   '쌈'],
#  ['스토리',
#   '부터',
#   '캐릭터',
#   '맵',
#   '그',
#   '모든',
#   '것',
#   '서든어택',
#   '배',
#   '꼈다',
#   '서든어택',
#   '재미있음',
#   '스레기겜',
#   '노잼',
#   'ㅗ',
#   '사지마',
#   '샘',
#   '후회',
#   '함',
#   '환',
#   'ㄴ',
#   '불',
#   'ㄱㄱ'],
#  ['일단',
#   '개',
#   '같',
#   '애',
#   '많이',
#   '개',
#   '같',
#   '애',
#   '그',
#   '니깐',
#   '개',
#   '같',
#   '애',
#   '아무튼',
#   '개',
#   '같은거',
#   '임'],
#  ['무료', '플레이', '인데', '한글', '이라고', '적혀있는데', '한글', '플레이', '안되네요', '개', '노답'],
#  ['어지러워', '못', '함', '왜삿', '지'],
#  ['한글', '지', '원', '해줘라', '한', '섭', '망했는데'],
#  ['자동차', '매니아', '에겐', '신의', '축복', '같은'],
#  ['딱',
#   '한마디',
#   '만',
#   '할게요',
#   '하고',
#   '시',
#   '계보',
#   '니',
#   '아침',
#   '시',
#   'ㄷㄷㄷ',
#   '겁나게',
#   '재밌습니다',
#   '아',
#   '옛날',
#   '퀘이크',
#   '하던',
#   '시절',
#   '떠오르고',
#   '울',
#   '펜',
#   '이나',
#   '둠',
#   '캐릭터',
#   '참전',
#   '하니',
#   '개',
#   '꿀이에',
#   '용'],
#  ['조', '작', '방법', '조이패드', '맞춰져있다긴', '하는', '데타', '격감', '종이', '때리는것보다', '못함'],
#  ['모드', '깔고', '싶다'],
#  ['재밌는데', '컨텐츠', '부족해요', '업뎃좀'],
#  ['발전', '가능성', '보이는', '나름', '꾸르잼'],
#  ['시절',
#   '방황',
#   '하던',
#   '바하',
#   '시리즈',
#   '분명',
#   '재미',
#   '있는데',
#   '액션',
#   '공포',
#   '스토리',
#   '묘',
#   '하게',
#   '조금씩',
#   '부족함',
#   '할인',
#   '때',
#   '구매',
#   '할',
#   '것',
#   '추천'],
#  ['적어도',
#   '풀',
#   '스크린',
#   '이랑',
#   '오버레이',
#   '지원',
#   '키',
#   '설정',
#   '지원',
#   '해야',
#   '하는',
#   '거',
#   '아닙니까',
#   '불친절함'],
#  ['김', '성보고', '하지마라'],
#  ['중력', '시스템', '답답해서', '못', '하겠습니다'],
#  ['저', '지금', '울고있음'],
#  ['진부한',
#   '러브스토리',
#   '지만',
#   '스토리',
#   '크게',
#   '신경',
#   '쓰지',
#   '않아도',
#   '배경',
#   '재미있다',
#   '신난다',
#   '와우',
#   '퀴즈',
#   '풀다',
#   '빡',
#   '칠수',
#   '있으니',
#   '힌트',
#   '볼수있는',
#   '슈팅게임',
#   '공략',
#   '책',
#   '보거나',
#   '인터넷',
#   '찾아보세요'],
#  ['평가', '들', '보고', '구매', '해보았다', '일단', '난', '환불', '했다', '무슨', '인지', '모르겠다'],
#  ['의외로', '노잼'],
#  ['왜', '내', '괴물', '하면', '약', '한', '거지'],
#  ['내',
#   '플랫포머',
#   '류',
#   '싫어하는걸',
#   '알',
#   '게',
#   '해준',
#   '스토리',
#   '심오하니',
#   '뭐',
#   '니',
#   '포장',
#   '들',
#   '짜임새',
#   '있게',
#   '짜놓',
#   '게',
#   '아니라',
#   '알려',
#   '준',
#   '게',
#   '없으니',
#   '자기',
#   '들',
#   '끼리',
#   '소설',
#   '쓰는거',
#   '뿐임'],
#  ['재밌지만', '고', '인물', '난장판', '노답'],
#  ['블옵', '깔끔하고', '재미있는것', '같아요', '한글화', '아니었으면', '걸렀을듯', 'ㅠㅠ'],
#  ['단점', '조', '작법', '밖에', '없다'],
#  ['솔직히', '거', '난이도', '씹오', '바', '개', '어려워'],
#  ['존망', '이라', '그렇지', '좋다', '원레', '파판', '시리즈', '좋지'],
#  ['ㅈㄴ', '멍청해서', '난이도', '최고', '올리', '고해', '야', '된다'],
#  ['콘솔',
#   '하면',
#   '음성',
#   '한국어',
#   '인데',
#   '하면',
#   '무조건',
#   '영어',
#   '자막',
#   '없음',
#   'ㄷㄷ',
#   '영어',
#   '자신',
#   '있으면',
#   '하시길'],
#  ['시간', '플레이', '타임', '동안', '뛰어다니는게', '시간', '인', '듯', '뜬금없이', '튕', '기는건', '덤'],
#  ['도전',
#   '과제',
#   '달성',
#   '도과',
#   '때문',
#   '회차',
#   '극',
#   '초반',
#   '까지',
#   '했는데',
#   '나름',
#   '괜찮음',
#   '달리기',
#   '없고',
#   '대쉬',
#   '딜레이',
#   '있어서',
#   '약간',
#   '불편함',
#   '전투',
#   '방식',
#   '괜찮음'],
#  ['전설', '시작', '입니다', '꼭', '추천', '해용'],
#  ['어렵다', '흑', '흑'],
#  ['멀티',
#   '지원',
#   '하지',
#   '않습니다',
#   '멀티',
#   '지원',
#   '하지',
#   '않습니다',
#   '멀티',
#   '지원',
#   '하지',
#   '않습니다'],
#  ['알수',
#   '없는',
#   '의미',
#   '들',
#   '가득',
#   '찬',
#   '퍼즐게임',
#   '처음',
#   '해보면',
#   '뭘',
#   '어쩌',
#   '라는',
#   '건지',
#   '계속',
#   '헤매게',
#   '된다',
#   '진짜',
#   '아무',
#   '것',
#   '알려주는게',
#   '없어서',
#   '오랜',
#   '시간',
#   '뻘',
#   '짓거리',
#   '하',
#   '게',
#   '만든다',
#   '색깔',
#   '별로',
#   '독특하게',
#   '꾸며진',
#   '맵',
#   '디자인',
#   '조차도',
#   '없었다면',
#   '쳐다도',
#   '안',
#   '봤을'],
#  ['추가', '시키고', '튜토리얼', '자세히', '만들어서', '초반', '플레이', '도움', '되게', '해줬음', '싶다'],
#  ['자동차', '구조', '알기에', '매우', '적합함'],
#  ['분', '딱', '분만', '했는데', '벌써', '지릴거', '같다', 'ㅈㄴ', '무섭네'],
#  ['노스',
#   '오브',
#   '워리어',
#   '보단',
#   '적지',
#   '만',
#   '버그',
#   '쩔고',
#   '공략',
#   '때문',
#   '골',
#   '아팠음',
#   '주인공',
#   '들',
#   '별로',
#   '년',
#   '넘어가는데',
#   '신작',
#   '안',
#   '나오는건',
#   '이런',
#   '이유',
#   '인가'],
#  ['드론', '때매', '해킹', '할', '수가', '없네'],
#  ['진행중', '매치', '들어가는', '것좀', '없애주세요', '제발'],
#  ['와우', '개꿀잼', '거', '마우스', '조종', '가능함', '미쳤음', '꿀잼'],
#  ['재미', '있는데', '고', '인물', '들', '많아서', '짜증나네요', 'ㅎㅎㅎ'],
#  ['일단',
#   '존나',
#   '개',
#   '적',
#   '화',
#   '좆',
#   '같음',
#   '절대로',
#   '하지마라',
#   '사양',
#   '낮은',
#   '사람',
#   '들',
#   '비',
#   '추천',
#   'ㅇㅇ'],
#  ['좋았던',
#   '점',
#   '라라',
#   '크로',
#   '포트',
#   '다시',
#   '만',
#   '날수',
#   '있는',
#   '거',
#   '밖',
#   '없고',
#   '잔',
#   '버그',
#   '까지는',
#   '이해',
#   '하는데',
#   '진짜',
#   '스토리',
#   '개',
#   '망',
#   '폐기물',
#   '수준',
#   '쉴드',
#   '쳐줄수가',
#   '없음',
#   '쉴드',
#   '패',
#   '고',
#   '싶음'],
#  ['네트워크', '오류', '때문', '멀티', '못', '하네', '존나', '개', '적', '화', '지리', '네'],
#  ['거', '멀티', '만', '됐다면', '비슷한', '들', '압살', '할', '수', '있었다'],
#  ['비', '추천'],
#  ['전선',
#   '확장',
#   '및',
#   '에너지',
#   '관리',
#   '소재',
#   '한',
#   '서서히',
#   '밀려',
#   '올라가는',
#   '전선',
#   '보면서',
#   '기뻐',
#   '할',
#   '수',
#   '있음'],
#  ['쒸익쒸익'],
#  ['사', '보삼', '후회', '안함'],
#  ['예상',
#   '한',
#   '그대로',
#   '내용',
#   '시간',
#   '낭비',
#   '비추',
#   '차라리',
#   '짱구',
#   '아빠',
#   '영상',
#   '배는',
#   '감동',
#   '적'],
#  ['재밋음', '단지', '어려움', '난이도', '도전', '두려워지는'],
#  ['초',
#   '짜리',
#   '용자',
#   '판',
#   '그',
#   '느낌',
#   '그대로',
#   '반드시',
#   '픽셀',
#   '판',
#   '으로',
#   '할',
#   '것',
#   '스팀',
#   '판',
#   '추가',
#   '된',
#   '그래픽',
#   '모드',
#   '하면',
#   '재미',
#   '반의',
#   '반의',
#   '반도',
#   '안됨',
#   '아쉬운',
#   '점',
#   '라면',
#   '판',
#   '있던',
#   '갤러리',
#   '모드',
#   '사라짐',
#   '으아',
#   '뻐킹'],
#  ['개', '재밌었', '슴', '데헷'],
#  ['휴대폰',
#   '으로',
#   '모모',
#   '랑',
#   '채팅',
#   '하며',
#   '임무',
#   '수행',
#   '하는',
#   '인디',
#   '공포',
#   '짧고',
#   '단순하며',
#   '한국어',
#   '지원',
#   '없습니다',
#   '세',
#   '일',
#   '많이',
#   '할',
#   '때',
#   '해보세요'],
#  ['겜', '시작', '한지', '분만', '애', '버그', '바닥', '으로', '무한', '빨려', '들어감'],
#  ['안',
#   '돼',
#   '무슨',
#   '문제',
#   '인',
#   '지는',
#   '모르겠지만',
#   '튜터링',
#   '끝나고',
#   '본',
#   '들어가기전에',
#   '하얀색',
#   '로딩',
#   '으로',
#   '정지후',
#   '안됨'],
#  ['대충',
#   '복수',
#   '한다는',
#   '내용',
#   '인',
#   '건',
#   '알겠지만',
#   '영어',
#   '라서',
#   '잘',
#   '못',
#   '알아',
#   '먹겠다',
#   '게다가',
#   '남부',
#   '사투리'],
#  ['아들',
#   '아',
#   '난',
#   '도대체',
#   '게',
#   '뭔',
#   '개',
#   '소린',
#   '지',
#   '알',
#   '아',
#   '먹지',
#   '못',
#   '하겠구나'],
#  ['층', '까지', '내려갔는데', '왜', '애', '들', '머리', '수집', '하', '냐', '존나', '무섭게'],
#  ['가격', '비', '해서', '재밌다'],
#  ['유저',
#   '한글화',
#   '사랑',
#   '입니다',
#   '스텔스',
#   '라',
#   '우드',
#   '재미있습니다',
#   '다만',
#   '버그',
#   '때문',
#   '헤맸던',
#   '기억',
#   '있네요',
#   '난이도',
#   '제',
#   '기준',
#   '에는',
#   '조',
#   '오금',
#   '있는',
#   '편',
#   '인데',
#   '조절',
#   '가능하니까',
#   '좋았습니다'],
#  ['보더',
#   '랜드',
#   '시리즈',
#   '진짜',
#   '극도',
#   '애정',
#   '있는거',
#   '아닌',
#   '이상',
#   '건너',
#   '뛰어도',
#   '무방',
#   '한',
#   '편임',
#   '그래도',
#   '에서',
#   '언급',
#   '되는',
#   '보스',
#   '여기',
#   '보스',
#   '이기도',
#   '하니까',
#   '싼값',
#   '으로',
#   '할인',
#   '하면',
#   '사서',
#   '해보는것도',
#   '나쁘진',
#   '않아요'],
#  ['짧게',
#   '즐',
#   '기기',
#   '에는',
#   '좋지만',
#   '달성',
#   '매우',
#   '귀찮음',
#   '주차',
#   '진행',
#   '하기에는',
#   '단순',
#   '반복',
#   '뿐',
#   '이라',
#   '흥미',
#   '떨어진다'],
#  ['왜',
#   '게',
#   '블랙',
#   '옵스',
#   '인가',
#   '아직도',
#   '모르겠고',
#   '좀비',
#   '겜',
#   '된거',
#   '같음',
#   '언제나',
#   '폭망'],
#  ['윈도우',
#   '으',
#   '구',
#   '동시',
#   '처음',
#   '화면',
#   '에서',
#   '깜박',
#   '거림',
#   '존재',
#   '하며',
#   '안',
#   '에서',
#   '건물',
#   '건설',
#   '할시',
#   '스크린샷',
#   '처럼',
#   '화면',
#   '렉',
#   '걸리는듯',
#   '한',
#   '상황',
#   '발생',
#   '합니다',
#   '다른',
#   '지역',
#   '갔다오면',
#   '그',
#   '현상',
#   '사라지지만',
#   '상당히',
#   '거슬리네요',
#   '그',
#   '외',
#   '에는',
#   '재미있게',
#   '플레이',
#   '하였습니다'],
#  ['지금', '생각', '해보면', '왜', '샀을까', '후회', '중', '워해머', '살껄'],
#  ['시리즈',
#   '안',
#   '하셔도',
#   '됩니다',
#   '하는',
#   '내내',
#   '짜증',
#   '과',
#   '지루함',
#   '가득했습니다',
#   '스토리',
#   '짜증나고',
#   '계속',
#   '등장',
#   '하는',
#   '딸',
#   '들',
#   '이야기',
#   '아주',
#   '루즈',
#   '하게',
#   '만',
#   '드',
#   '네',
#   'ㅗ'],
#  ['훌륭한', '협동'],
#  ['인단',
#   '전',
#   '미국',
#   'ㄴ',
#   '에서',
#   '어',
#   'ㅣㄱ',
#   '구요',
#   '인',
#   '게인',
#   '어더껀',
#   '한으지',
#   '몬으게서'],
#  ['스팀',
#   '출시',
#   '한지',
#   '얼마나',
#   '지났는데',
#   '아직도',
#   '멀티',
#   '제대로',
#   '안되냐',
#   '멀티',
#   '지향',
#   '무슨',
#   '강제',
#   '솔로',
#   '잉'],
#  ['남주',
#   '목소리',
#   '졸라',
#   '좆',
#   '병신임',
#   '하반신마비',
#   '라',
#   '제데로',
#   '걷지도',
#   '못함',
#   '한마디',
#   '인생헛살',
#   '으',
#   '바리',
#   '색기'],
#  ['설정', '창', '에서', '어치', '브먼트', '플', '리즈', '입력', '하면', '도전', '과제', '줌'],
#  ['전체',
#   '적',
#   '으로',
#   '깔끔하고',
#   '친절하며',
#   '배경',
#   '캐릭터',
#   '스토리',
#   '전부',
#   '마음',
#   '들었다',
#   '전투',
#   '시스템',
#   '익숙해지는데',
#   '오랜',
#   '시간',
#   '걸렸고',
#   '쾌적한',
#   '전투',
#   '하기까지',
#   '꽤',
#   '오랜',
#   '시간',
#   '걸렸다',
#   '정통',
#   '중',
#   '에선',
#   '손',
#   '꼽',
#   '정도',
#   '완성',
#   '높다'],
#  ['무한',
#   '로딩',
#   '고치',
#   '라고',
#   '족',
#   '같아서',
#   '진짜',
#   '왜',
#   '계속',
#   '빨핑',
#   '만',
#   '처',
#   '잡혀',
#   '진짜',
#   '개화',
#   '나게',
#   '문의',
#   '못',
#   '하고',
#   '진짜',
#   '짠',
#   'ㅇㄻㅈㄹ',
#   '진짜',
#   '니',
#   '자',
#   'ㅓ',
#   '릱'],
#  ['조작',
#   '열',
#   '라',
#   '불편함',
#   '근데',
#   '플스',
#   '패드',
#   '왜',
#   '안',
#   '먹는지',
#   '아는',
#   '사람',
#   '검색',
#   '해봐도',
#   '안',
#   '나와요'],
#  ['어떻게', '하는', '건지', '모르겟지만', '재밋엇는', '보', '여서', '사는데'],
#  ['재미', '없어', '억지로', '했지만', '시간', '남아도', '하지', '말', '하야', '할', '인거', '같습니다'],
#  ['옛', '향수', '이제', '느끼자'],
#  ['패드', '하다가', '버그', '먹고', '정지', '되길래', '냅다', '패드', '던지고', '환불', '합니다'],
#  ['중병', '같은', '대사', '잘', '버티면', '좋은', '작품', '입니다'],
#  ['목욕', '타월', '주인공', '말고', '금발', '드래곤', '주인공', '으로', '뒷', '내용', '더주세요'],
#  ['최적화', '좆망'],
#  ['노잼', '라이브러리', '늘리는', '용', '입죠'],
#  ['엄청난',
#   '타',
#   '격감',
#   '수도',
#   '없이',
#   '많은',
#   '무기',
#   '몇',
#   '년',
#   '기다렸는지',
#   '모른다',
#   'ㅠㅠ',
#   '만들어',
#   '주세요'],
#  ['같이', '하실', '분', '물리엔진', '좆', '같네'],
#  ['아니',
#   '이런',
#   '경우',
#   '어딨냐',
#   '진짜',
#   '돈존',
#   '나게',
#   '뜯어가네',
#   '사면',
#   '모해',
#   '아이디',
#   '만들어',
#   '또',
#   '들어가서',
#   '아이핀',
#   '만들어',
#   '그',
#   '랜',
#   '는데',
#   '안되잖아',
#   '모',
#   '시스템',
#   '이따',
#   '구로',
#   '만드냐',
#   '컴퓨터',
#   '잘',
#   '몰라서',
#   '모르겠는데',
#   '진짜',
#   '빡치네'],
#  ['별',
#   '생각',
#   '없이',
#   '시간',
#   '때우기',
#   '용',
#   '스토리',
#   '따라가면',
#   '되는',
#   '거기',
#   '때문',
#   '그렇게',
#   '무역',
#   '열심히',
#   '할',
#   '필요',
#   '없습니다',
#   '열심히',
#   '했다가',
#   '허무하게',
#   '끝난',
#   '케이스',
#   'ㅎㅎ',
#   '딱',
#   '스토리',
#   '필요한',
#   '만큼만',
#   '얻고',
#   '진행',
#   '하고',
#   '하면',
#   '될',
#   '거',
#   '같네요'],
#  ['처음',
#   '엔',
#   '재미있게',
#   '플레이',
#   '했는데',
#   '나중',
#   '가니깐',
#   '스테이지',
#   '구성',
#   '지루해지고',
#   '스토리',
#   '뭔가',
#   '크게',
#   '있을',
#   '것',
#   '같다가',
#   '허무하고',
#   '아무튼',
#   '나쁜',
#   '이라고',
#   '말',
#   '하긴',
#   '그렇지만',
#   '사서',
#   '하기엔',
#   '아까운',
#   '것',
#   '같아요'],
#  ['난', '신', '되면', '안된다는것을', '알려주는'],
#  ['좋은데',
#   '좋은데',
#   '멀티',
#   '플레이',
#   '환경',
#   '최악',
#   '중',
#   '최악',
#   '모든',
#   '장점',
#   '뒤엎',
#   '정도',
#   '화',
#   '딱지',
#   '나서',
#   '비추'],
#  ['계속', '해서', '하게', '되는', '재미', '있다'],
#  ['죳', '쓰레기', '코', '박스', '사라'],
#  ['예전',
#   '샀는데',
#   '지금',
#   '생각',
#   '하면',
#   '왜',
#   '만들어졌는지',
#   '의문',
#   '드는',
#   '이다',
#   '절때',
#   '사지마라',
#   '것',
#   '보다',
#   '훨신',
#   '재미있는',
#   '무료',
#   '널리',
#   '고',
#   '널렸다'],
#  ['첫',
#   '장전',
#   '성공하는데',
#   '시간',
#   '걸림',
#   '생각',
#   '보다',
#   '익숙해지면',
#   '장전',
#   '금방',
#   '하는데',
#   '빠요엔',
#   '만',
#   '안',
#   '만나면',
#   '됨',
#   '글',
#   '고',
#   '겜',
#   '악평',
#   '하는',
#   '놈',
#   '들',
#   '이해',
#   '안되는게',
#   '원',
#   '이라',
#   '는걸',
#   '생각',
#   '안',
#   '하나',
#   '원',
#   '짜',
#   '리',
#   '이정',
#   '물건',
#   '이면',
#   '충분히',
#   '잘',
#   '만들어진거',
#   '아님'],
#  ['협동', '하며', '웨이브', '막는게', '재밌는'],
#  ['발', '이딴', '걸', '돈', '받고', '파냐'],
#  ['아픈', '아픈', '조류', '인형', '뽑기', '기계', '입', '니까'],
#  ['유일한', '불만', '였으나', '업데이트'],
#  ['처음',
#   '에는',
#   '배우는게',
#   '혼란',
#   '스럽고',
#   '어렵지만',
#   '배우는',
#   '과정',
#   '이나',
#   '배우고',
#   '나서',
#   '퀄리티',
#   '있는',
#   '연설',
#   '과',
#   '그래픽',
#   '신나는',
#   '브금',
#   '두',
#   '둠칫',
#   '하',
#   '게',
#   '해줍니다'],
#  ['여러',
#   '모로',
#   '무리수',
#   '낸',
#   '느낌',
#   '입니다',
#   '시리즈',
#   '계속',
#   '해도',
#   '되나',
#   '싶습니다',
#   '단간',
#   '플레이',
#   '하고',
#   '가있다구',
#   '여기',
#   '서',
#   '이어진다고',
#   '하고',
#   '생각',
#   '했는데',
#   '이어지면',
#   '안',
#   '됐습니다',
#   '제작사',
#   '단간',
#   '시리즈',
#   '제작',
#   '멈춰라'],
#  ['거',
#   '멀티',
#   '관련',
#   '해서',
#   '로그인',
#   '하려는대',
#   '왜',
#   '이메일',
#   '이랑',
#   '조합',
#   '안',
#   '맞다는',
#   '문구',
#   '나오내요',
#   '안',
#   '돼는건',
#   '가요'],
#  ['할인', '하길래', '샀는데', '재밌네요', 'ㅎㅎ', '멍청한', '용서', '되는', '정도'],
#  ['잠입', '플레이', '하기에는', '지루하다'],
#  ['히오스', '다음', '갓', '겜'],
#  ['쓰레기',
#   '란말',
#   '이여기',
#   '붙는다',
#   '거',
#   '깔을면',
#   '당신',
#   '하드디스크',
#   '공간',
#   '부족해진다',
#   '절대',
#   '까질',
#   '마라'],
#  ['겜', '손', '안', '가는데요'],
#  ['싸게',
#   '사서',
#   '재미있게',
#   '했습니다',
#   '근데',
#   '해변',
#   '다른',
#   '맵',
#   '비',
#   '하면',
#   '기대',
#   '미만',
#   '이네',
#   '그래도',
#   '재미있게',
#   '했습니다'],
#  ['겁나', '재밋다', '이런', '어드벤쳐', '액션게임', '왜', '이제', '알았을까'],
#  ['쓰레기', '같은', '모니터', '해상도', '지', '맘', '대로', '바꿔', '버리네'],
#  ['지금', '해도', '재밌다', '옛날', '생각', '존나', '나네'],
#  ['한국', '오세요', '맥밀런', '당신', '기다립니다'],
#  ['올',
#   '오래전',
#   '사서',
#   '받은거지만',
#   '지금',
#   '에서야',
#   '추천',
#   '레이싱게임',
#   '잘못',
#   '하는',
#   '에게도',
#   '나름',
#   '신선했던'],
#  ['스테파노',
#   '까진',
#   '좋았는데',
#   '뭔',
#   '사이비',
#   '사무엘',
#   '잭슨',
#   '나온',
#   '후론',
#   '개',
#   'ㅄ',
#   '같음',
#   '크리',
#   '쳐도',
#   '그닥'],
#  ['같이', '하면', '재밌을꺼', '같긴'],
#  ['하자', '마자', '졸리', '고', '지루해서', '껐습닏'],
#  ['정확히',
#   '보는데',
#   '분',
#   '걸렸네요',
#   '분기점',
#   '있지만',
#   '이벤트',
#   '씬',
#   '차이',
#   '일',
#   '뿐',
#   '이고',
#   '엔딩',
#   '바뀐다거나',
#   '하는건',
#   '없습니다',
#   '참고',
#   '하는',
#   '이유',
#   '트레이딩카드',
#   '가격',
#   '때문',
#   '입니다'],
#  ['내',
#   '리뷰',
#   '남기는',
#   '일이',
#   '거의',
#   '없는데',
#   '화',
#   '딱지',
#   '나서',
#   '한마디',
#   '남김',
#   '대전',
#   '액션',
#   '스틱',
#   '지원이',
#   '거지',
#   '같고',
#   '대각선',
#   '입력',
#   '안되는게',
#   '말',
#   '되냐',
#   '와',
#   '무슨',
#   '생각',
#   '으로',
#   '만들었는지',
#   '모르지만',
#   '얼른',
#   '수정',
#   '되길',
#   '바람'],
#  ['금방', '엔딩', '볼', '수', '있어서', '좋네요', '엔딩', '까지', '지루하지', '않음'],
#  ['육식',
#   '교육',
#   '식',
#   '교육',
#   '식',
#   '교육',
#   '식',
#   '교육',
#   '식',
#   '교육',
#   '식',
#   '교육',
#   '식',
#   '교육',
#   '식',
#   '교육',
#   '식',
#   '교'],
#  ['네', '재밌네', '염', 'ㅋ', '지울거', '얌', 'ㅋㅋㅋㅋ'],
#  ['현질', '유도', '심함', '접음'],
#  ['평가',
#   '할',
#   '때',
#   '감정',
#   '치우치지',
#   '않고',
#   '성적',
#   '으로',
#   '판단',
#   '하려고',
#   '노력',
#   '한다',
#   '뭐랄까',
#   '음',
#   '욕',
#   '나오는',
#   '이다',
#   '내',
#   '왜',
#   '돈',
#   '주고',
#   '샀을까',
#   '하는',
#   '반성',
#   '하며',
#   '오늘',
#   '갓',
#   '겜',
#   '히오스',
#   '스킨',
#   '산다'],
#  ['엔딩',
#   '보고',
#   '리뷰',
#   '씁니다',
#   '진',
#   '엔딩',
#   '까지',
#   '보는데',
#   '난이도',
#   '어렵긴',
#   '그만큼',
#   '진',
#   '엔딩',
#   '때',
#   '엄청',
#   '소름',
#   '돋았네요',
#   'ㅋㅋㅋㅋ',
#   '한마디',
#   '갓',
#   '겜'],
#  ['하나',
#   '메세지',
#   '지속',
#   '적',
#   '으로',
#   '주입',
#   '시킵니다',
#   '그거',
#   '니',
#   '손',
#   '탓임',
#   '분하게도',
#   '맞는말이라',
#   '분노',
#   '삭힌',
#   '채',
#   '열심히',
#   '미트',
#   '보이',
#   '꼬라박',
#   '게',
#   '됩니다',
#   '이렇게',
#   '악랄한',
#   '입니다',
#   '여러분'],
#  ['좋은', '이긴', '합니다만', '매치', '밸런싱', '기존', '보다', '떨어지는', '느낌', '랄', '까요'],
#  ['조작',
#   '감',
#   '거지같다는',
#   '비추',
#   '들',
#   '장애',
#   '인가',
#   '달리기',
#   '할',
#   '때',
#   '마우스',
#   '움직일수',
#   '없는게',
#   '익숙하지',
#   '않다거나',
#   '설명',
#   '불친절한거는',
#   '인정',
#   '하겠는데'],
#  ['게', '테크모', '축구', '아니고'],
#  ['서버', '문제', '만', '해결', '된다면'],
#  ['인생', '냠냠'],
#  ['히', '야', '내', '초', '멈출', '수', '있다'],
#  ['저',
#   '디제잉',
#   '하고있었습니다',
#   '거기',
#   '엔',
#   '귀엽지만',
#   '괴상한',
#   '강아지',
#   '있었으며',
#   '한참',
#   '디제잉',
#   '하다가',
#   '막바지',
#   '에가',
#   '서',
#   '음악',
#   '저장',
#   '하는',
#   '구간',
#   '에서',
#   '튕',
#   '겼습니다',
#   '끝'],
#  ['금', '혁신', '적', '인', '나치', '죽이기', '섹스', '섹스', '오'],
#  ['인디',
#   '새로운',
#   '시대',
#   '열게',
#   '해준',
#   '아이작',
#   '번',
#   '제의',
#   '리',
#   '버스',
#   '작품',
#   '복불복',
#   '인',
#   '만큼',
#   '어려우면서도',
#   '템빨',
#   '과',
#   '컨트롤',
#   '승부',
#   '한다',
#   '자체',
#   '폭력',
#   '성',
#   '종교',
#   '성',
#   '불쾌감',
#   '줄',
#   '수',
#   '있으니',
#   '처음',
#   '하는',
#   '사람',
#   '입장',
#   '에선',
#   '주의',
#   '하여',
#   '진행',
#   '해야하는',
#   '입니다'],
#  ['훌륭합니다'],
#  ['왜', '친구', '초대', '하', '면', '세션', '만든다고만', '나오고', '초대', '불가능한건', '가요'],
#  ['분명히', '오늘', '하나', '깨야지', '하고', '들어갔는데', '왜', '금방', '나왔지'],
#  ['반복',
#   '된는',
#   '중독',
#   '성',
#   '이렇게',
#   '재미있을지는',
#   '몰랐다',
#   '구린',
#   '그래픽',
#   '근데',
#   '것',
#   '인디',
#   '계',
#   '에서는',
#   '평타',
#   '제외',
#   '하고는',
#   '흠집',
#   '낼',
#   '건',
#   '수가',
#   '없다',
#   '제작자',
#   '추가',
#   '컨텐츠',
#   '만',
#   '기다리자'],
#  ['아니', '시', '댕', '멀티', '할꺼면', '하지마', '셈', '랙오져'],
#  ['ㄹㅇ', '나와가지고', '골랐', '읍니', '아니', '예쁘자', '여'],
#  ['구',
#   '작',
#   '히트',
#   '맨',
#   '과',
#   '코',
#   '만',
#   '도스',
#   '즐겨',
#   '했던',
#   '사람',
#   '들이라면',
#   '분명',
#   '즐겁게',
#   '할',
#   '수',
#   '있는',
#   '탑',
#   '뷰',
#   '실시간',
#   '전략',
#   '잠입',
#   '드디어',
#   '돌아왔습니다',
#   '쉐도우',
#   '택틱스',
#   '에서',
#   '보여줬던',
#   '그',
#   '기분',
#   '다시',
#   '한번',
#   '느껴',
#   '보세요'],
#  ['뭐', '야', '히바', '얼굴', '돌려줘요'],
#  ['으',
#   '어',
#   '컨트롤',
#   '자신있는데',
#   '같은',
#   '조',
#   '작',
#   '감',
#   '으로는',
#   '못',
#   '버티겠다',
#   '그래픽',
#   '귀욤',
#   'ㅎ'],
#  ['시리즈', '모두', '최고', '예요'],
#  ['네',
#   '코옵',
#   '이란',
#   '게',
#   '생겻',
#   '어',
#   '그래도',
#   '아직',
#   '까진',
#   '많이',
#   '컨텐츠',
#   '부족',
#   '한게임'],
#  ['산지', '달', '됬는데', '무료', '이벤트', '하네', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['걍튕김', '하지마', '셈'],
#  ['세이브',
#   '안됨',
#   '겜',
#   '관리자',
#   '권한',
#   '으로',
#   '해도',
#   '시발',
#   '난',
#   '폴더',
#   '왜',
#   '안',
#   '생기냐고',
#   '시',
#   '발람',
#   '들',
#   '아'],
#  ['던',
#   '오브',
#   '워',
#   '편',
#   '편',
#   '까지',
#   '나왔는데',
#   '편이',
#   '가장',
#   '재미있음',
#   '렐릭',
#   '리마',
#   '만',
#   '해도',
#   '잘',
#   '팔릴꺼',
#   '같은데',
#   '울',
#   '티',
#   '메이트',
#   '아포칼립스',
#   '모드',
#   '쓰면',
#   '혼자',
#   '노',
#   '재미',
#   '쏠쏠함'],
#  ['조작', '법도', '간단하고', '터', '트리', '맛', '아주', '좋은', '임'],
#  ['대체',
#   '자면서',
#   '뭔',
#   '짓',
#   '쳐하길래',
#   '무기',
#   '잃어버리고',
#   '자면서',
#   '뭘',
#   '쳐',
#   '먹길래',
#   '중독',
#   '걸리는거냐',
#   '생존',
#   '가장',
#   '한',
#   '운',
#   '시험',
#   '하는',
#   '좆망',
#   '겜',
#   '이다'],
#  ['캐릭터', '설정', '구리', '고', '뜬금', '없다'],
#  ['제목', '때문', '장난', '으로', '샀는데', '재미없었', '엉'],
#  ['왜',
#   '사람',
#   '들',
#   '찬양',
#   '하나',
#   '했는데',
#   '이번',
#   '무비',
#   '보고',
#   '저',
#   '빠져',
#   '버렸네요',
#   '로서',
#   '높이',
#   '평가',
#   '받는',
#   '그날',
#   '빨리',
#   '왔으면',
#   '좋겠습니다'],
#  ['저', '인생', '최대', '실수', '중', '하나', '다운', '받고', '플레이', '했다는', '겁니다', 'ㅎ'],
#  ['좋은', '아이템', '떠', '달라', '고', '바라는것보다', '버튼', '연', '타하는게', '빠름'],
#  ['확실히',
#   '로얄',
#   '만들면서',
#   '삽질',
#   '하긴',
#   '했지만',
#   '기본',
#   '좋기',
#   '때문',
#   '재미있습니다',
#   '저',
#   '추천',
#   '하겠습니다'],
#  ['핵', '노잼', '플래쉬', '하지말자'],
#  ['철권',
#   '이나',
#   '소울칼리버',
#   '질렸다면',
#   '추천',
#   '솔직히',
#   '것',
#   '만',
#   '한',
#   '격투',
#   '겜',
#   '못',
#   '본듯'],
#  ['졎망겜', 'ㅗㅗㅗㅗㅗ'],
#  ['왜', '삼각', '빤', '쓰는', '없을까'],
#  ['실행', '안된다'],
#  ['세', '입자', '갑', '이다'],
#  ['시간', '내', '즐길', '수', '있는', '짧은', '동심'],
#  ['한글화',
#   '라',
#   '매',
#   '한글화',
#   '라',
#   '매',
#   '아직',
#   '번역',
#   '덜',
#   '된',
#   '부분',
#   '상당수',
#   '입니다만',
#   '네',
#   '단점',
#   '그',
#   '겁니다'],
#  ['병신',
#   '같은',
#   '시작',
#   '하',
#   '자마자',
#   '주장',
#   '은퇴',
#   '소식',
#   '메인',
#   '뉴스',
#   '전북',
#   '이동국',
#   '선수',
#   '교체',
#   '하는데',
#   '이름',
#   '면',
#   '누가',
#   '누군데',
#   '그러면',
#   '별명',
#   '설정',
#   '이나',
#   '넣어주던가',
#   '뭐',
#   '한다고',
#   '프레임',
#   '죽어라고',
#   '떨어지고',
#   '다른거',
#   '할게요',
#   '빠셍'],
#  ['사탄', '만든'],
#  ['할거',
#   '겁나',
#   '많음',
#   '친구',
#   '랑',
#   '하면',
#   '배',
#   '됨',
#   '아직',
#   '앞서',
#   '해보기',
#   '임',
#   '계속',
#   '할거',
#   '많아짐'],
#  ['처음',
#   '엔',
#   '갓',
#   '겜',
#   '이라고',
#   '했는데',
#   '개망겜',
#   '이네',
#   '액셀',
#   '이랑',
#   '설정',
#   '할려니',
#   '버그',
#   '나서',
#   '설정',
#   '안',
#   '돼는',
#   'ㅈ',
#   '망겜'],
#  ['개', '뻥튀기'],
#  ['중독', '성', '오지', 'ㅁㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['오픈월드', '형', '로그라이크', '난이도', '상당함', '맵', '많고'],
#  ['플레이',
#   '타임',
#   '꽤',
#   '되는',
#   '일텐데',
#   '힘들게',
#   '깨고',
#   '보는',
#   '엔딩',
#   '전부',
#   '비극',
#   '이란',
#   '말',
#   '듣고',
#   '손',
#   '때었다'],
#  ['맥스', '뒤', '돌려차기', '본', '적', '있는가'],
#  ['뭐',
#   '좋아요',
#   '아직',
#   '미완성',
#   '인걸',
# ...
#  ['마우스',
#   '라서',
#   '편한다',
#   '이제',
#   '곳',
#   '자주포',
#   '나올꺼고',
#   '인원',
#   '수나',
#   '늘려주지',
#   '워',
#   '게',
#   '놈',
#   '들',
#   '핑',
#   '폭도',
#   '조금',
#   '있다',
#   '키',
#   '보드',
#   '와',
#   '마우스',
#   '라서',
#   '좀더',
#   '편한것',
#   '같다'],
#  ['카',
#   '메카',
#   '닉',
#   '시뮬레이션',
#   '중',
#   '입문',
#   '용',
#   '으론',
#   '좋은',
#   '입니다',
#   '기본',
#   '적',
#   '인',
#   '차량',
#   '구조',
#   '대해',
#   '선',
#   '알수있으나',
#   '생략',
#   '되어',
#   '표현',
#   '안된',
#   '부품',
#   '많으니',
#   '으로',
#   '차량',
#   '정비',
#   '진지하게',
#   '하고싶으신',
#   '분',
#   '들',
#   '다른',
#   '작품',
#   '추천',
#   '드립니다'],
#  ['나름',
#   '대로',
#   '좋은',
#   '시간',
#   '보냈던',
#   '것',
#   '같습니다',
#   '여기',
#   '돈',
#   '쓸',
#   '생각',
#   '들지',
#   '않는군요'],
#  ['으악', '내', '돈', '일단', '화면', '부터가', '혐'],
#  ['답답해도', '할만', '함'],
#  ['까지', '개발', '할줄은', '몰랐습니다'],
#  ['동생',
#   '쌤',
#   '스토리',
#   '짧고',
#   '멀티',
#   '재미없음',
#   '험블',
#   '이라',
#   '샀지',
#   '아니면',
#   '인디',
#   '보다',
#   '못',
#   '한',
#   '수준',
#   '거기',
#   '다가',
#   '호러',
#   '에서',
#   '벗어나',
#   '미래',
#   '변함'],
#  ['재미있음',
#   '단점',
#   '초반',
#   '부',
#   '퀘스트',
#   '깨는것도',
#   '지루하고',
#   '초반',
#   '부가',
#   '진짜',
#   '지독할',
#   '정도',
#   '재미없다',
#   '수정',
#   '후반',
#   '부는',
#   '재미없다'],
#  ['원피스',
#   '해적',
#   '무쌍',
#   '나름',
#   '괜찮은',
#   '재미',
#   '잘',
#   '만들어진',
#   '이네',
#   '곧',
#   '나올',
#   '기대',
#   '되네요'],
#  ['쩝'],
#  ['내', '생', '최악', '순간', '구', '매', '버튼', '누른', '그', '순간'],
#  ['도전',
#   '과제',
#   '해금',
#   '용',
#   '이다',
#   '솔직히',
#   '이라고',
#   '부를',
#   '수',
#   '있을지',
#   '조차',
#   '의문',
#   '이다',
#   '도전',
#   '과제',
#   '위해',
#   '선',
#   '회',
#   '차가',
#   '필수',
#   '소요',
#   '시간',
#   '약',
#   '분',
#   '내외'],
#  ['점프', '어렵고', '금방', '끝남'],
#  ['뭐',
#   '부터',
#   '먹을지',
#   '행복한',
#   '고민',
#   '드는',
#   '뷔페',
#   '남',
#   '들',
#   '한계',
#   '볼',
#   '때',
#   '가능성',
#   '보았다'],
#  ['재밌었구요', '엔딩', '까지', '딱', '시간', '걸렸는데', '아주', '좋아요'],
#  ['산지',
#   '일만',
#   '플레이',
#   '타임',
#   '시간',
#   '돌파',
#   '거',
#   '생각',
#   '보다',
#   '재밌습니다',
#   '굳이',
#   '씬',
#   '안',
#   '넣었어도',
#   '팔렸을거',
#   '같은데'],
#  ['한', '방이', '면', '너', '한', '방', '나도', '한', '방'],
#  ['아포칼립스', '헬기', '날아다니고', '현대', '무기', '사용', '하는', '배경'],
#  ['확장팩', '하나', '밖에', '없', '엉'],
#  ['알고한', '면', '재밌는', '이긴', '하겠지만', '모르고', '하면', '뭐', '뭔', '지도', '모름'],
#  ['꿀잼', '시간', '가는', '줄', '모름', '가끔', '프리징', '있어서', '짜증남', '유', '플레이', '필요'],
#  ['매칭', '안되는데', '무슨', '하라', '겁', '니까', 'ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ'],
#  ['재밌고',
#   '그래픽',
#   '좋은데',
#   '왜',
#   '많이',
#   '안',
#   '하지',
#   '폰',
#   '수준',
#   '이긴',
#   '큰',
#   '화면',
#   '으로',
#   '봐서',
#   '좋음',
#   '재밋읍',
#   '니'],
#  ['가성',
#   '비',
#   '뛰어난',
#   '작품',
#   '이지만',
#   '싼',
#   '가격',
#   '만큼',
#   '조금',
#   '나사',
#   '빠진',
#   '부분',
#   '있는',
#   '액션',
#   '다른건',
#   '괜찮았지만',
#   '상태',
#   '이상',
#   '거',
#   '장애물',
#   '이나',
#   '적',
#   '너무나도',
#   '짜증났다',
#   '부담',
#   '없는',
#   '가격',
#   '므',
#   '구매',
#   '말리진',
#   '않겠지만',
#   '기대',
#   '크면',
#   '실망할',
#   '수도',
#   '있는',
#   '정도',
#   '작품'],
#  ['디펜스', '즐기', '신다면', '추천'],
#  ['버그', '덩어리'],
#  ['재미있는', '그런데', '아직', '컨텐츠', '부족'],
#  ['거', '왜', '에러', '떠서', '실행', '안되나요'],
#  ['노', '마더'],
#  ['한번', '하면', '할게', '없음'],
#  ['원작', '에서', '불만', '이었던', '점', '완벽하게', '개선', '된', '점', '좋았습니다'],
#  ['제대로',
#   '만들어라',
#   '한',
#   '시간',
#   '번',
#   '씩',
#   '튕기',
#   '니',
#   '제대로',
#   '할',
#   '수가',
#   '없네요',
#   '시간',
#   '넘어서',
#   '환불',
#   '안되고',
#   '만원',
#   '넘는',
#   '돈',
#   '허공',
#   '으로',
#   '날아감'],
#  ['빨리', '내', '셈'],
#  ['할만은',
#   '하나',
#   '서버',
#   '노답',
#   '개',
#   '적',
#   '화',
#   '온갖',
#   '버그',
#   '난무',
#   '하는',
#   '겜',
#   '이돈',
#   '주고',
#   '차라리',
#   '아크',
#   '서바이벌',
#   '이나',
#   '러스트',
#   '하는것을',
#   '추천',
#   '한다'],
#  ['컨트롤',
#   '더럽게',
#   '불편함',
#   '왜',
#   '있는지',
#   '모르겠는',
#   '회피',
#   '시스템',
#   '카메라',
#   '돌리는것도',
#   '불가능함',
#   '여러분',
#   '싸다고',
#   '사지',
#   '마세요'],
#  ['역시', '갓', '작품'],
#  ['시리즈',
#   '전부',
#   '이상하리만치',
#   '똑같은',
#   '양산',
#   '이라는',
#   '느낌',
#   '지우기가',
#   '힘듬',
#   '퍼즐게임',
#   '인',
#   '척',
#   '하는',
#   '리듬게임',
#   '잦은',
#   '버그',
#   '인한',
#   '재',
#   '시작',
#   '특히',
#   '마지막',
#   '탄에서',
#   '버그',
#   '걸리면',
#   '멘붕',
#   '하는',
#   '현상',
#   '노란',
#   '벽',
#   '움직',
#   '이지',
#   '말아야하는데',
#   '움직인다거나'],
#  ['많은', '아이템', '과', '제작', '조합', '등', '매우', '컨텐츠', '많음'],
#  ['뭔가',
#   '잘',
#   '만들었는데',
#   '제자리',
#   '느낌',
#   '잔',
#   '버그',
#   '꽤',
#   '있고',
#   '노가다',
#   '라는',
#   '느낌',
#   '많이',
#   '들지만',
#   '제일',
#   '아쉬운건',
#   '옆',
#   '동네',
#   '비해',
#   '던전',
#   '수도',
#   '대략',
#   '개',
#   '한정',
#   '돼있고',
#   '마을',
#   '실질',
#   '적',
#   '으로',
#   '이용',
#   '할',
#   '수',
#   '있는',
#   '도서관',
#   '맵',
#   '연습장',
#   '세',
#   '가지',
#   '밖',
#   '없음'],
#  ['화난다'],
#  ['우리나라', '정치', '판', '잘', '묘사', '한'],
#  ['성장', '재미', '기술', '쓰는', '재미', '있다'],
#  ['아르마', '좋습니다'],
#  ['괜히', '조선인', '믿었다가', '피봄'],
#  ['분량', '한번', '놀랐고', '클리어', '할', '때', '춤추는거', '보고', '한번', '놀랐다'],
#  ['처음',
#   '시',
#   '작',
#   '부분',
#   '꼬리',
#   '아님',
#   '머리',
#   '하면서',
#   '동전',
#   '던지기',
#   '하는',
#   '부분',
#   '에서',
#   '계속',
#   '튕',
#   '기는데',
#   '거',
#   '어떻게',
#   '된',
#   '건지',
#   '모르겠네요',
#   'ㅠㅠ'],
#  ['주사위', '던져졌다'],
#  ['하다', '보면', '알', '수', '있다', '아무', '의미', '없다는', '것'],
#  ['버스',
#   '왜',
#   '늦',
#   '지역',
#   '교통',
#   '왜',
#   '이따',
#   '군',
#   '맨날',
#   '욕',
#   '하시는',
#   '분',
#   '들',
#   '께',
#   '추천',
#   '하는',
#   '버스',
#   '빨리',
#   '보내고싶어도',
#   '못',
#   '보내고',
#   '교통',
#   '좋게',
#   '만들어주고',
#   '싶어도',
#   '도로',
#   '사정',
#   '때문',
#   '혈압',
#   '만',
#   '오르는',
#   '교통',
#   '회사',
#   '들',
#   '고충',
#   '충분히',
#   '느낄',
#   '수',
#   '있는',
#   '입니다'],
#  ['가족', '끼리', '사랑', '빠지는', '이라니', '망측', '스러워요'],
#  ['거',
#   '어어어어',
#   '어',
#   '엄처',
#   '어어',
#   '엉',
#   '어렵습니다',
#   '근데',
#   '원',
#   '값',
#   '해',
#   '시간',
#   '훅',
#   '가네요'],
#  ['재미없음',
#   '서버',
#   '한자리',
#   '수고',
#   '하는',
#   '사람',
#   '거의',
#   '없다이거',
#   '할',
#   '바',
#   '엔',
#   '그',
#   '돈',
#   '아',
#   '꺼서',
#   '딴',
#   '겜',
#   '사라',
#   '그래픽',
#   '부터',
#   '모든',
#   '게',
#   '비호감'],
#  ['고블린', '환', '풍구', '버그', '에서', '포기', '했습니다'],
#  ['음컨텐즈', '없음'],
#  ['당신',
#   '서부',
#   '시대',
#   '카우보이',
#   '들',
#   '레버액션',
#   '윈체스터',
#   '라이플',
#   '들고',
#   '스핀',
#   '코킹',
#   '하면서',
#   '빵빵',
#   '쏘는',
#   '혈투',
#   '동경',
#   '하셨습니까'],
#  ['게망겜'],
#  ['재밌는데',
#   '가격',
#   '만',
#   '쌌으면',
#   '좋았을듯',
#   '난',
#   '싸게',
#   '사서',
#   '만족함',
#   '근데',
#   '욕',
#   '먹어서',
#   '사람',
#   '들',
#   '빠져나가니까',
#   '큐',
#   '느려',
#   '짐',
#   'ㅠㅠ'],
#  ['생각', '보다', '플레이', '타임', '좋고', '그렇게', '질리지도', '않고', '은근', '히', '꿀잼'],
#  ['플래시',
#   '스마트폰',
#   '타워',
#   '디펜스',
#   '중',
#   '에서',
#   '젤',
#   '추천',
#   '하고싶은',
#   '작품',
#   '난이도',
#   '밸런스',
#   '꽤',
#   '잘',
#   '되있어서',
#   '지루하지',
#   '않음',
#   '영웅',
#   '업글',
#   '위해',
#   '서',
#   '반복',
#   '아주',
#   '약간',
#   '필요하긴',
#   '굳이',
#   '디럭스',
#   '에디',
#   '션',
#   '살',
#   '정도',
#   '아님'],
#  ['현질', '필수'],
#  ['재미있었다', '그런데', '후속작', '안', '나오고', '계속', '만', '나온다', '너무한거', '아닌가'],
#  ['멀미', '조심'],
#  ['한글패치', '나올', '때', '까지', '존버', '하겠습니다'],
#  ['컨셉', '좋았으나', '시드', '마이어', '이름', '값', '아까운'],
#  ['희', '대의', '갓', '겜', '그니까', '한글', '패치', '해줘', '뉴비', '유입', '시급한'],
#  ['로그라이크',
#   '류',
#   '처음',
#   '해보는데',
#   '처음',
#   '적응하기가',
#   '어렵지',
#   '하면',
#   '할수록',
#   '재밌는',
#   '입니다',
#   '재밌어요',
#   '하세요',
#   '두',
#   '번하세요'],
#  ['심플', '하면서도', '재밌는', '레이싱게임'],
#  ['처음',
#   '플레이',
#   '했을',
#   '때',
#   '그',
#   '공포',
#   '감',
#   '조작',
#   '감',
#   '타격',
#   '감',
#   '잊을수가',
#   '없습니다'],
#  ['나폴레옹', '프랑스', '만', '고를수', '있을줄은', '몰랐네'],
#  ['하다가', '졸았음', '원정', '도면', '살', '만', '할듯'],
#  ['내', '제일', '싫어하는', '몬스터', '피', '하기'],
#  ['일단', '디', '엘', '씨', '걸러', '야만', '한다', '구리'],
#  ['역대',
#   '해본',
#   '콜옵',
#   '중',
#   '가장',
#   '다이나믹',
#   '하면서도',
#   '벨런스',
#   '잘',
#   '맞춰진',
#   '멀티',
#   '유저',
#   '갈수록',
#   '줄어든다는게',
#   '너무나도',
#   '아쉽다'],
#  ['할인', '할', '때', '구매', '해서', '코옵', '으로', '가볍게', '즐', '기기', '엔', '괜찮았던'],
#  ['와', '버그', '없', '서나', '만'],
#  ['고', '인물', '천지'],
#  ['집중',
#   '해서',
#   '하다',
#   '보니',
#   '분',
#   '끝나있네요',
#   '정식',
#   '판',
#   '만',
#   '기다려져요',
#   '강한',
#   '총',
#   '필요합니다'],
#  ['재미있으나', '엔딩'],
#  ['년',
#   '만에',
#   '위닝',
#   '구매',
#   '했습니다',
#   '매번',
#   '평이',
#   '복합',
#   '적',
#   '이라던가',
#   '좋지',
#   '않아서',
#   '구매',
#   '꺼렸는데',
#   '오랜',
#   '만',
#   '시리즈',
#   '사서',
#   '해보니',
#   '만족스럽고',
#   '좋네요'],
#  ['흠',
#   '재밌긴하지만',
#   '조금',
#   '어려운',
#   '감',
#   '있습니다',
#   '저',
#   '뒤',
#   '갈수록',
#   '막혀서',
#   '공략',
#   '봤습니다'],
#  ['난이도', '높네요'],
#  ['거',
#   '업데이트',
#   '한',
#   '뒤',
#   '갑자기',
#   '문제',
#   '거리',
#   '면서',
#   '온라인',
#   '안되요',
#   '왜',
#   '그런',
#   '거',
#   '죠'],
#  ['뭐', '한글화', 'ㅋㅋㅋㅋ', '좋다', '지금', '간다', '기다려라'],
#  ['도로시',
#   '한테',
#   '몰입',
#   '하면',
#   '우울해질',
#   '수도',
#   '있어요',
#   '근데',
#   '그거',
#   '빼고는',
#   '재밌는듯',
#   '그레텔',
#   '얼굴',
#   '무서워',
#   'ㅜㅠ',
#   '일',
#   '내내',
#   '봤더니',
#   '꿈',
#   '에서',
#   '나올거',
#   '같',
#   '애',
#   '여'],
#  ['갓', '흥겜', '이다'],
#  ['되게',
#   '재밌어',
#   '보',
#   '여서',
#   '구매',
#   '했는데',
#   '설치',
#   '하고서',
#   '깔았다가',
#   '지우기만',
#   '몇번',
#   '째',
#   '인지',
#   '모르겠네요',
#   '왜',
#   '자꾸',
#   '작동',
#   '중지',
#   '되었다고',
#   '뜰까',
#   '설정',
#   '안',
#   '맞나',
#   '괜히',
#   '돈',
#   '주',
#   '고사',
#   '서',
#   '환불',
#   '하고싶네요',
#   'ㅠㅠ'],
#  ['시리즈',
#   '물',
#   '꼭',
#   '이어서',
#   '하는',
#   '스타일',
#   '이라',
#   '구매',
#   '했는데',
#   '클레멘타인',
#   '펜심',
#   '으로',
#   '플레이',
#   '했네요'],
#  ['클래식', '한', '이라지만', '슈퍼마리오', '지금', '해도', '재밌는데'],
#  ['하시면',
#   '심령',
#   '고자',
#   '될수',
#   '잇다',
#   '느끼고',
#   '명작',
#   '인거',
#   '같다는',
#   '생각',
#   '과',
#   '함께',
#   '깨',
#   '버려서',
#   '대',
#   '단',
#   '한게임',
#   '이다'],
#  ['추상',
#   '적',
#   '이고',
#   '상징',
#   '적',
#   '인',
#   '스토리',
#   '간단한',
#   '퍼즐',
#   '몰입',
#   '할',
#   '수',
#   '있게',
#   '해줍니다',
#   '그런데',
#   '지도',
#   '와',
#   '리셋',
#   '버튼',
#   '화면',
#   '뜨지',
#   '않고',
#   '설명',
#   '같은',
#   '것',
#   '들',
#   '뜨지',
#   '않는',
#   '건',
#   '버그',
#   '인가요',
#   '것',
#   '때문',
#   '지도',
#   '필요한',
#   '관',
#   '부터는',
#   '진행',
#   '안되네요'],
#  ['지역', '락', '풀려서', '살때', '꼬쇼', '안', '해도', '됨', 'ㅅㄱ'],
#  ['아직', '개발', '중'],
#  ['탐욕',
#   '개인',
#   '어떻게',
#   '반영',
#   '되는지',
#   '잘',
#   '와',
#   '닿는',
#   '작품',
#   '이네',
#   '기대',
#   '되네요',
#   '추천',
#   '합니다'],
#  ['설치', '한', '뒤', '실행', '하', '니까', '검은', '창', '만', '보이', '고', '실행', '안되네요'],
#  ['팦바', '개', '훔쳐', '간', '새', '기', '들', '때문', '접음'],
#  ['할거면',
#   '하던가',
#   '왜',
#   '코',
#   '옵하는데',
#   '지',
#   '들만',
#   '알아듣는',
#   '용어',
#   '쓰고',
#   '지랄',
#   '일까',
#   '난',
#   '하러',
#   '온',
#   '거지',
#   '병신',
#   '같은',
#   '군사',
#   '용어',
#   '배우러',
#   '온',
#   '게',
#   '아닌데'],
#  ['재밌어요',
#   '여러분',
#   '아주',
#   '훌륭합니다',
#   '새로',
#   '시작',
#   '하시는',
#   '분',
#   '들',
#   '가문',
#   '어디가',
#   '입하',
#   '실지',
#   '모르시겠다면',
#   '저',
#   '한테',
#   '귓말',
#   '보내주세요',
#   '같이',
#   '천천히',
#   '가봅시다',
#   '지역',
#   '운천',
#   '입니다'],
#  ['맵', '만', '크면', '뭐해', '할께', '없잖아'],
#  ['얄팍한',
#   '스페이스',
#   '슈터',
#   '워낙',
#   '스페이스',
#   '들어가는',
#   '중',
#   '복잡한',
#   '물건',
#   '많다',
#   '보니',
#   '처럼',
#   '얄팍한',
#   '것',
#   '나름',
#   '매력',
#   '있다',
#   '장르',
#   '대한',
#   '기초',
#   '적',
#   '인',
#   '지식',
#   '만',
#   '있다면',
#   '아주',
#   '가볍게',
#   '즐길',
#   '수',
#   '있는'],
#  ['공기청정기',
#   '주인공',
#   '과',
#   '손발',
#   '말리',
#   '비틀어지는',
#   '스토리',
#   '빼고',
#   '나면',
#   '의외로',
#   '할만',
#   '한',
#   '수작',
#   '겜'],
#  ['도저히',
#   '그',
#   '많은',
#   '돈',
#   '들여',
#   '만들었다고는',
#   '볼수',
#   '없는',
#   '퀄리티',
#   '뻔한',
#   '스토리',
#   '졸작',
#   '아니지만',
#   '펀딩할때',
#   '돈',
#   '생각',
#   '하면',
#   '영락',
#   '없는',
#   '졸작',
#   '딱',
#   '그',
#   '저',
#   '그런'],
#  ['프레임', '느린거', '같은', '렉', '또는', '끊김', '현상', '돈', '아까', '움'],
#  ['머',
#   '전시',
#   '짝퉁',
#   '인가',
#   '발',
#   '적',
#   '화',
#   '컨트롤',
#   '엄청',
#   '불편하다',
#   '소방관',
#   '인공',
#   '지능',
#   '답답하다'],
#  ['푸른',
#   '바다',
#   '속',
#   '돌아다니면서',
#   '작살',
#   '쏘아',
#   '물고기',
#   '사냥',
#   '특별한',
#   '사진',
#   '촬영',
#   '매장',
#   '된',
#   '보물',
#   '탐색',
#   '합니다',
#   '위',
#   '행동',
#   '하면',
#   '돈',
#   '획득',
#   '할',
#   '수',
#   '있으며',
#   '좋은',
#   '장비',
#   '구매',
#   '할',
#   '수',
#   '있죠'],
#  ['재밌다', '개발', '사가', '한글패치', '오', '통수치고', '결국', '한글패치', '무산', '됨'],
#  ['베데스다',
#   '넷',
#   '연동',
#   '했는데도',
#   '디럭스',
#   '에디',
#   '션',
#   '특전',
#   '안',
#   '뜨는데',
#   '도데',
#   '체',
#   '어떻게',
#   '해야',
#   '뜨는거',
#   '임'],
#  ['졸라맨', '주제', '타', '격감', '지리', '네'],
#  ['재미있긴한데',
#   '후반',
#   '갈수록',
#   '지루함',
#   '스토리',
#   '막장',
#   '재미',
#   'ㅎㅎ',
#   '깨는데',
#   '시간',
#   '정도',
#   '걸리는',
#   '것',
#   '같은데',
#   '제',
#   '돈',
#   '주고',
#   '플레이',
#   '하기엔',
#   '아까',
#   '움',
#   '세',
#   '일',
#   '할',
#   '때',
#   '사시',
#   '고',
#   '덕후',
#   '아니면',
#   '필요없을듯',
#   '함',
#   '난',
#   '안',
#   '샀음'],
#  ['뒤진',
#   '겜',
#   '업뎃',
#   '하',
#   '라고',
#   '하고',
#   '로딩',
#   '걸리고',
#   '계속',
#   '업뎃만뜸',
#   '입구',
#   '컷',
#   '감동',
#   '받아',
#   '비추',
#   '날립니다'],
#  ['아직',
#   '미흡한',
#   '점',
#   '많지만',
#   '얼리',
#   '억',
#   '세',
#   '스',
#   '이기도',
#   '하고',
#   '많은',
#   '발전',
#   '가능성',
#   '있다고',
#   '봄'],
#  ['양민',
#   '학살',
#   '갓',
#   '갓',
#   '발암',
#   '핵',
#   '유저',
#   '공',
#   '속',
#   '핵',
#   '사용자',
#   '봤음',
#   '있는',
#   '갓',
#   '겜임',
#   '초보',
#   '단지',
#   '무기',
#   '재',
#   '조',
#   '재료',
#   '일',
#   '뿐',
#   '이고',
#   '많이',
#   '쳐',
#   '발려서',
#   '새소리',
#   '가꾸와',
#   '가져와로',
#   '들릴',
#   '지경'],
#  ['데누보', '왜안', '했는지', '모르겠음', '업데이트', '기다린답니다', '복돌', '들은', '서', '쭉', '해줄듯'],
#  ['초반',
#   '출시',
#   '단계',
#   '에서는',
#   '퀘스트',
#   '무기',
#   '퀘등',
#   '단',
#   '순',
#   '반복',
#   '들',
#   '많지만',
#   '업데이트',
#   '이후',
#   '수많은',
#   '퀘',
#   '들',
#   '생겨',
#   '도전',
#   '과',
#   '수집',
#   '욕구',
#   '불러',
#   '옴'],
#  ['넘',
#   '모',
#   '심심한',
#   '벨트',
#   '스',
#   '크롤',
#   '겜',
#   '인',
#   '것',
#   '이야',
#   '뭐',
#   '있다',
#   '싶은',
#   '배경',
#   '에서',
#   '삽질',
#   '하다',
#   '보면',
#   '아무',
#   '것',
#   '없고',
#   '체력',
#   '만',
#   '줄줄',
#   '빠지는게',
#   '원더보이',
#   '키드',
#   '사',
#   '다가',
#   '하는게',
#   '낫',
#   '지',
#   '싶다'],
#  ['왜', '스피드', '고속', '으로', '하지', '않았는데', '배', '이상', '빠르게', '느껴짐'],
#  ['개인',
#   '적',
#   '으로',
#   '별로',
#   '좋아하지',
#   '않아서',
#   '거르다',
#   '사람',
#   '들',
#   '하도',
#   '갓',
#   '겜',
#   '갓',
#   '겜',
#   '거리',
#   '길',
#   '래',
#   '세',
#   '일',
#   '때',
#   '구매',
#   '해서',
#   '해봤는데',
#   '역시',
#   '난',
#   '좋아하지',
#   '않는다는',
#   '사실',
#   '한번',
#   '알',
#   '게',
#   '해줬다',
#   '전투',
#   '재미없었어'],
#  ['툼레이더',
#   '리부트',
#   '시리즈',
#   '모두',
#   '가지',
#   '고',
#   '있어',
#   '구매',
#   '했지만',
#   '이번',
#   '작품',
#   '스토리',
#   '볼륨',
#   '빈약하고',
#   '최적화',
#   '최적화',
#   '대로',
#   '안되어',
#   '있고',
#   '이전',
#   '툼레이더',
#   '시리즈',
#   '모험',
#   '과',
#   '전투',
#   '두',
#   '가지',
#   '잡았다면',
#   '이번',
#   '작품',
#   '두',
#   '가지',
#   '놓침',
#   '내',
#   '걸',
#   '왜',
#   '샀지'],
#  ['자체',
#   '좋음',
#   '최적화',
#   '존',
#   '좋습니다',
#   '어려워요',
#   '어려워요',
#   '조작',
#   '베리',
#   '이지',
#   '해도',
#   '등',
#   '하기',
#   '힘들어요',
#   '개인',
#   '적',
#   '으로',
#   '차탓',
#   '이라고',
#   '생각',
#   '한',
#   '다만',
#   '마음',
#   '어려워',
#   '못',
#   '하겠네',
#   '몸',
#   '으',
#   '하하',
#   '핳',
#   '하하',
#   '하하',
#   '핳',
#   '크라이',
#   '썸',
#   '모어'],
#  ['재밌는데', '문제', '사람', '적고', '쏘고', '난', '후', '몇', '초', '뒤', '반동', '나옴'],
#  ['집',
#   '쓰레기',
#   '같은',
#   '컴',
#   '이라',
#   '그런지',
#   '아주',
#   '렉',
#   '심합니다',
#   '무료',
#   '되서',
#   '가지시는',
#   '분들',
#   '많아서',
#   '저',
#   '가져',
#   '봤더니',
#   '아주',
#   '렉',
#   '심하더군',
#   '뇨',
#   '컴',
#   '아주',
#   '쓰',
#   '렉',
#   '인',
#   '분',
#   '들',
#   '전',
#   '윈',
#   '비트',
#   '사용',
#   '하지',
#   '않는걸',
#   '추천',
#   '합니다'],
#  ['퍼즐', '푸는', '중', '인데', '진짜', '재밌다'],
#  ['거',
#   '일단',
#   '키',
#   '면',
#   '재밌는데',
#   '키기',
#   '싫음',
#   '요새',
#   '한글패치',
#   '때문',
#   '레드',
#   '훅',
#   '말',
#   '많던데',
#   '추천',
#   '줄',
#   '지',
#   '비추줄지',
#   '고민',
#   '하다가',
#   '비추',
#   '줌'],
#  ['와',
#   '조작',
#   '매우',
#   '어렵습니다',
#   '사양',
#   '의외로',
#   '고',
#   '사양',
#   '인',
#   '것',
#   '물론',
#   '이고',
#   '롤러코스터',
#   '에서의',
#   '컨트롤',
#   '잊으십시오',
#   '격자',
#   '없는',
#   '엄청난',
#   '입니다',
#   '마인크래프트',
#   '처럼',
#   '격자',
#   '없어서',
#   '매우',
#   '매우',
#   '건물',
#   '짓기',
#   '힘듭니다'],
#  ['미드',
#   '보다',
#   '으로',
#   '먼저',
#   '접',
#   '한',
#   '왕좌',
#   '처음',
#   '엔',
#   '당황',
#   '했다고',
#   '해야하나',
#   '초반',
#   '화살표',
#   '나오길래',
#   '겁나',
#   '눌렀는데',
#   '안되고',
#   '마우스',
#   '안되고',
#   '맞나',
#   '계속',
#   '초반',
#   '죽다가',
#   '키',
#   '보드',
#   '눌러서',
#   '되서',
#   '많이',
#   '당황',
#   '하고',
#   '개',
#   '빡친',
#   '역시',
#   '텔테일',
#   '입니다',
#   '나비효과',
#   '짜',
#   '짱'],
#  ['한국',
#   '사람인',
#   '대',
#   '핑',
#   '적당한',
#   '서버',
#   '하나',
#   '없고',
#   '내',
#   '서버',
#   '만들수도',
#   '없어서',
#   '재',
#   '대로',
#   '할수가',
#   '없네요'],
#  ['새끼',
#   '들',
#   '보다',
#   '살',
#   '먹고',
#   '휴대폰',
#   '또래',
#   '여자',
#   '번호',
#   '하나',
#   '없는',
#   '내',
#   '불상',
#   '하다',
#   'ㅣ',
#   '발'],
#  ['이나', '하자'],
#  ['주인공', '급하다고', '대학원생', '연구', '샘플', '막', '제공', '해서', '영원히', '고통', '받는', '내용'],
#  ['거',
#   '모바일',
#   '있는',
#   '그대로',
#   '옮긴',
#   '이다',
#   '이식',
#   '할',
#   '때',
#   '에는',
#   '인터페이스',
#   '라도',
#   '바꾸는게',
#   '맞지',
#   '않을까'],
#  ['이야', '멀티', '나옴'],
#  ['음', '권장', '사양', '맞춰있는데', '프레임', '떨어지네요'],
#  ['하면서', '각', '종파', '일로', '하면서', '웃기', '좋은'],
#  ['재밌는데',
#   '오타쿠',
#   '들',
#   '왜',
#   '이리',
#   '불타',
#   '오름',
#   '조작',
#   '감도',
#   '정도',
#   '면',
#   'ㅍㅅㅌㅊ',
#   '아닌가',
#   '따리',
#   '으로',
#   '원활하게',
#   '잘',
#   '돌아가는데'],
#  ['개인',
#   '적',
#   '으론',
#   '과대',
#   '평가',
#   '받는',
#   '이라고',
#   '생각',
#   '합니다',
#   '처음',
#   '엔',
#   '전투',
#   '시스템',
#   '참',
#   '괜찮다',
#   '생각',
#   '했는데',
#   '얼마',
#   '안되서',
#   '금방',
#   '지겨워지네요',
#   '생각',
#   '돌이켜',
#   '보니',
#   '유저',
#   '사로잡을만한',
#   '새로운',
#   '시스템',
#   '부족하고',
#   '여러',
#   '요소',
#   '들',
#   '잘',
#   '융합',
#   '한',
#   '일',
#   '뿐',
#   '이라는',
#   '결론',
#   '내렸습니다'],
#  ['어디', '선', '받은', '무료', '생각', '보다', '괜찮은데', '돈', '주고', '하긴', '아깝긴', '하다'],
#  ['안되서', '사놓고', '하지도', '못', '함'],
#  ['유사', '존윅'],
#  ['분', '정도', '했다가', '멀미', '머리', '아프고', '토', '할', '정도', '심해서', '환불', '함'],
#  ['그때', '부터', '였어요', '제', '쳐', '맞고', '다닌게', '흙흙'],
#  ['처음',
#   '튜토리얼',
#   '하고',
#   '난',
#   '느낌',
#   '롤',
#   'ㅋㅋㅋ',
#   '근데',
#   '재미없',
#   '습',
#   '롤',
#   '액션',
#   '성은',
#   '없으으면서',
#   '롤',
#   '같고',
#   '도타',
#   '타',
#   '격감',
#   '없으면서',
#   '도타',
#   '같음'],
#  ['좀비', '몰려옴', '디펜스', '겜'],
#  ['배경음악', '덕분', '엔딩', '까지'],
#  ['으아', '진짜', '발', '적', '화', '진짜'],
#  ['실행'],
#  ['노가다', '성', '심해', '재미', '떨어뜨리기', '때문', '비', '추천', '드립니다'],
#  ['캐릭터', '잘생겨서', '물릴', '때', '마다', '넘나리', '슬퍼', 'ㅜ'],
#  ['팀', '한번', '밀리', '면', '아무', '것', '못', '함'],
#  ['뭔', '지', '잘', '모르겠다', 'ㅇ'],
#  ['평가',
#   '에서',
#   '다루는',
#   '대상',
#   '너무나도',
#   '무섭습니다',
#   '성',
#   '무서워서',
#   '아주',
#   '지려',
#   '버리',
#   '겄소'],
#  ['충각', '제일', '강하다'],
#  ['솔직히', '서버', '만', '괜찮으면', '갓', '겜임'],
#  ['우와',
#   '바이브',
#   '컨트롤러',
#   '트리',
#   '거의',
#   '내',
#   '구성',
#   '걱정',
#   '될',
#   '정도',
#   '정신없이',
#   '플',
#   '래',
#   '했습니다',
#   '아직',
#   '캠페인',
#   '밖에',
#   '못',
#   '해봤지만',
#   '꼭',
#   '해보셔야',
#   '합니다'],
#  ...]

# %%
X = s_otk_l
Y = np.array(data['label'])

# %%
x_data, tt_x, y_data, tt_y = train_test_split(X, Y, test_size = 0.3, random_state = 22)
t_x, v_x, t_y, v_y = train_test_split(x_data, y_data, test_size = 0.2, random_state = 22)

# %%
tk = Tokenizer()
tk.fit_on_texts(t_x)

# %%
word_num = len([w for w in sorted(list(tk.word_counts.items()), key = lambda x: x[1]) if w[1] > 4]) + 1

# %%
tk = Tokenizer(num_words = word_num)
tk.fit_on_texts(t_x)

# %%
t_t_x = tk.texts_to_sequences(t_x)
t_v_x = tk.texts_to_sequences(v_x)
t_tt_x = tk.texts_to_sequences(tt_x)

# %%
drop_t = [idx for idx, sentence in enumerate(t_t_x) if len(sentence) < 1]
drop_v = [idx for idx, sentence in enumerate(t_v_x) if len(sentence) < 1]
drop_tt = [idx for idx, sentence in enumerate(t_tt_x) if len(sentence) < 1]

# %%
t_t_x = np.delete(t_t_x, drop_t, axis = 0)
t_y = np.delete(t_y, drop_t, axis = 0)
t_v_x = np.delete(t_v_x, drop_v, axis = 0)
v_y = np.delete(v_y, drop_v, axis = 0)
t_tt_x = np.delete(t_tt_x, drop_tt, axis = 0)
tt_y = np.delete(tt_y, drop_tt, axis = 0)
# Out:
# C:\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
p_l = max([len(pad_sequences(t_t_x)[0]), len(pad_sequences(t_v_x)[0]), len(pad_sequences(t_tt_x)[0])])

t_x = pad_sequences(t_t_x, maxlen = p_l)
v_x = pad_sequences(t_v_x, maxlen = p_l)
tt_x = pad_sequences(t_tt_x, maxlen = p_l)

# %%
preprocessed_data = {}
preprocessed_data['train_x'] = t_x
preprocessed_data['train_y'] = t_y
preprocessed_data['test_x'] = tt_x
preprocessed_data['test_y'] = tt_y
preprocessed_data['validation_x'] = v_x
preprocessed_data['validation_y'] = v_y
preprocessed_data['token'] = tk
preprocessed_data['word_num'] = word_num
preprocessed_data['sentence_len'] = p_l
preprocessed_data['stop_words'] = st

# %%
with open('preprocessed_data.pickle', 'wb') as fw:
    pickle.dump(preprocessed_data, fw)
